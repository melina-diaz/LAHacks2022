# %%
import requests, json, time, csv
from plotly.io import write_html
import plotly.express as px
import pandas as pd

# %%
def map(API_KEY, company_name):
    if type(company_name) != str:
        raise TypeError
    MAX_NUM_RECORDS = -1

    # NO CHANGES NEEDED BELOW HERE
    PDL_URL = "https://api.peopledatalabs.com/v5/person/search"
    request_header = {
        "Content-Type": "application/json",
        "X-api-key": API_KEY
    }

    ES_QUERY = {
        "query": {
            "bool": {
                "must": [
                    {
                        "term": {
                            "job_company_name": company_name
                        }
                    }
                ]
            }
        }
    }
    
    num_records_to_request = 100
    params = {
        "dataset": "street_address",
        "query": json.dumps(ES_QUERY),
        "size": num_records_to_request,
        "pretty": True
    }
    
    # Pull all results in multiple batches
    batch = 1
    all_records = []
    start_time = time.time()
    while batch == 1 or params["scroll_token"]:
        if MAX_NUM_RECORDS != -1:
            # Update num_records_to_request
            # Compute the number of records left to pull
            num_records_to_request = MAX_NUM_RECORDS - len(all_records)
            # Clamp this number between 0 and 100
            num_records_to_request = max(0, min(num_records_to_request, 100))

        if num_records_to_request == 0:
            break

        params["size"] = num_records_to_request
        response = requests.get(PDL_URL, headers=request_header, params=params).json()

        if batch == 1:
            print(f"{response['total']} available records in this search")

        all_records.extend(response.get("data", []))
        params["scroll_token"] = response.get("scroll_token")
        print(f"Retrieved {len(response.get('data', []))} records in batch {batch}")
        batch += 1

        if params["scroll_token"]:
            time.sleep(6)   # avoid hitting rate limit thresholds
    
    end_time = time.time()
    runtime = end_time - start_time

    print(f"Successfully recovered {len(all_records)} profiles in "
          f"{batch} batches [{runtime} seconds]")


    def save_profiles_to_csv(profiles, filename, fields=[], delim=","):
        """Save profiles to csv (utility function)"""

        # Define header fields
        if fields == [] and len(profiles) > 0:
            fields = profiles[0].keys()
            
        with open(filename, "w", encoding="utf-8") as csvfile:
            # Write csv file
            writer = csv.writer(csvfile, delimiter=delim)

            # Write Header:
            writer.writerow(fields)

            count = 0
            for profile in profiles:
                # Write Body:
                writer.writerow([profile[field] for field in fields])
                count += 1
                print(f"Wrote {count} lines to: '{filename}'")
                
    # Use utility function to save profiles to csv
    csv_header_fields = ['job_company_location_geo', 'job_company_location_street_address',
                         'job_company_location_address_line_2',
                         'location_street_address', 'location_address_line_2', 'location_geo']
    csv_filename = company_name + "_employees.csv"
    save_profiles_to_csv(all_records, csv_filename, csv_header_fields)
    df = pd.read_csv(csv_filename)
    df['lat'] = df['location_geo'].apply(lambda s: float(s.split(',')[0]))
    df['lon'] = df['location_geo'].apply(lambda s: float(s.split(',')[1]))
    # used Mapbox for map with streets
    token_name = 'pk.eyJ1IjoidHJhY3ljaGFybGVzMTA4IiwiYSI6ImNsMjJmdmUzajFmeXcza3BkOXgwOWZoNW4ifQ.bFv6klpNU8XWRbEJ0zk1Dw'
    px.set_mapbox_access_token(token_name)
    fig = px.density_mapbox(df, lat = 'lat', lon = 'lon', zoom=15, mapbox_style='carto-positron', radius = 10)
    fig.update_layout(margin={"r":0, "t":0, "l":0, "b":0})
    fig.show()
    write_html(fig, company_name + '_employees.html')

# %%
map("a79cd2fea39460c9c8f8c66673d30a34a79c59654050e441b63268dcf28186c3", "twitch")
# Out:
# 401 available records in this search
# Retrieved 100 records in batch 1
# Retrieved 100 records in batch 2
# Retrieved 100 records in batch 3
# Retrieved 100 records in batch 4
# Retrieved 1 records in batch 5
# Retrieved 0 records in batch 6
# Successfully recovered 401 profiles in 7 batches [39.94179892539978 seconds]
# Wrote 1 lines to: 'twitch_employees.csv'
# Wrote 2 lines to: 'twitch_employees.csv'
# Wrote 3 lines to: 'twitch_employees.csv'
# Wrote 4 lines to: 'twitch_employees.csv'
# Wrote 5 lines to: 'twitch_employees.csv'
# Wrote 6 lines to: 'twitch_employees.csv'
# Wrote 7 lines to: 'twitch_employees.csv'
# Wrote 8 lines to: 'twitch_employees.csv'
# Wrote 9 lines to: 'twitch_employees.csv'
# Wrote 10 lines to: 'twitch_employees.csv'
# Wrote 11 lines to: 'twitch_employees.csv'
# Wrote 12 lines to: 'twitch_employees.csv'
# Wrote 13 lines to: 'twitch_employees.csv'
# Wrote 14 lines to: 'twitch_employees.csv'
# Wrote 15 lines to: 'twitch_employees.csv'
# Wrote 16 lines to: 'twitch_employees.csv'
# Wrote 17 lines to: 'twitch_employees.csv'
# Wrote 18 lines to: 'twitch_employees.csv'
# Wrote 19 lines to: 'twitch_employees.csv'
# Wrote 20 lines to: 'twitch_employees.csv'
# Wrote 21 lines to: 'twitch_employees.csv'
# Wrote 22 lines to: 'twitch_employees.csv'
# Wrote 23 lines to: 'twitch_employees.csv'
# Wrote 24 lines to: 'twitch_employees.csv'
# Wrote 25 lines to: 'twitch_employees.csv'
# Wrote 26 lines to: 'twitch_employees.csv'
# Wrote 27 lines to: 'twitch_employees.csv'
# Wrote 28 lines to: 'twitch_employees.csv'
# Wrote 29 lines to: 'twitch_employees.csv'
# Wrote 30 lines to: 'twitch_employees.csv'
# Wrote 31 lines to: 'twitch_employees.csv'
# Wrote 32 lines to: 'twitch_employees.csv'
# Wrote 33 lines to: 'twitch_employees.csv'
# Wrote 34 lines to: 'twitch_employees.csv'
# Wrote 35 lines to: 'twitch_employees.csv'
# Wrote 36 lines to: 'twitch_employees.csv'
# Wrote 37 lines to: 'twitch_employees.csv'
# Wrote 38 lines to: 'twitch_employees.csv'
# Wrote 39 lines to: 'twitch_employees.csv'
# Wrote 40 lines to: 'twitch_employees.csv'
# Wrote 41 lines to: 'twitch_employees.csv'
# Wrote 42 lines to: 'twitch_employees.csv'
# Wrote 43 lines to: 'twitch_employees.csv'
# Wrote 44 lines to: 'twitch_employees.csv'
# Wrote 45 lines to: 'twitch_employees.csv'
# Wrote 46 lines to: 'twitch_employees.csv'
# Wrote 47 lines to: 'twitch_employees.csv'
# Wrote 48 lines to: 'twitch_employees.csv'
# Wrote 49 lines to: 'twitch_employees.csv'
# Wrote 50 lines to: 'twitch_employees.csv'
# Wrote 51 lines to: 'twitch_employees.csv'
# Wrote 52 lines to: 'twitch_employees.csv'
# Wrote 53 lines to: 'twitch_employees.csv'
# Wrote 54 lines to: 'twitch_employees.csv'
# Wrote 55 lines to: 'twitch_employees.csv'
# Wrote 56 lines to: 'twitch_employees.csv'
# Wrote 57 lines to: 'twitch_employees.csv'
# Wrote 58 lines to: 'twitch_employees.csv'
# Wrote 59 lines to: 'twitch_employees.csv'
# Wrote 60 lines to: 'twitch_employees.csv'
# Wrote 61 lines to: 'twitch_employees.csv'
# Wrote 62 lines to: 'twitch_employees.csv'
# Wrote 63 lines to: 'twitch_employees.csv'
# Wrote 64 lines to: 'twitch_employees.csv'
# Wrote 65 lines to: 'twitch_employees.csv'
# Wrote 66 lines to: 'twitch_employees.csv'
# Wrote 67 lines to: 'twitch_employees.csv'
# Wrote 68 lines to: 'twitch_employees.csv'
# Wrote 69 lines to: 'twitch_employees.csv'
# Wrote 70 lines to: 'twitch_employees.csv'
# Wrote 71 lines to: 'twitch_employees.csv'
# Wrote 72 lines to: 'twitch_employees.csv'
# Wrote 73 lines to: 'twitch_employees.csv'
# Wrote 74 lines to: 'twitch_employees.csv'
# Wrote 75 lines to: 'twitch_employees.csv'
# Wrote 76 lines to: 'twitch_employees.csv'
# Wrote 77 lines to: 'twitch_employees.csv'
# Wrote 78 lines to: 'twitch_employees.csv'
# Wrote 79 lines to: 'twitch_employees.csv'
# Wrote 80 lines to: 'twitch_employees.csv'
# Wrote 81 lines to: 'twitch_employees.csv'
# Wrote 82 lines to: 'twitch_employees.csv'
# Wrote 83 lines to: 'twitch_employees.csv'
# Wrote 84 lines to: 'twitch_employees.csv'
# Wrote 85 lines to: 'twitch_employees.csv'
# Wrote 86 lines to: 'twitch_employees.csv'
# Wrote 87 lines to: 'twitch_employees.csv'
# Wrote 88 lines to: 'twitch_employees.csv'
# Wrote 89 lines to: 'twitch_employees.csv'
# Wrote 90 lines to: 'twitch_employees.csv'
# Wrote 91 lines to: 'twitch_employees.csv'
# Wrote 92 lines to: 'twitch_employees.csv'
# Wrote 93 lines to: 'twitch_employees.csv'
# Wrote 94 lines to: 'twitch_employees.csv'
# Wrote 95 lines to: 'twitch_employees.csv'
# Wrote 96 lines to: 'twitch_employees.csv'
# Wrote 97 lines to: 'twitch_employees.csv'
# Wrote 98 lines to: 'twitch_employees.csv'
# Wrote 99 lines to: 'twitch_employees.csv'
# Wrote 100 lines to: 'twitch_employees.csv'
# Wrote 101 lines to: 'twitch_employees.csv'
# Wrote 102 lines to: 'twitch_employees.csv'
# Wrote 103 lines to: 'twitch_employees.csv'
# Wrote 104 lines to: 'twitch_employees.csv'
# Wrote 105 lines to: 'twitch_employees.csv'
# Wrote 106 lines to: 'twitch_employees.csv'
# Wrote 107 lines to: 'twitch_employees.csv'
# Wrote 108 lines to: 'twitch_employees.csv'
# Wrote 109 lines to: 'twitch_employees.csv'
# Wrote 110 lines to: 'twitch_employees.csv'
# Wrote 111 lines to: 'twitch_employees.csv'
# Wrote 112 lines to: 'twitch_employees.csv'
# Wrote 113 lines to: 'twitch_employees.csv'
# Wrote 114 lines to: 'twitch_employees.csv'
# Wrote 115 lines to: 'twitch_employees.csv'
# Wrote 116 lines to: 'twitch_employees.csv'
# Wrote 117 lines to: 'twitch_employees.csv'
# Wrote 118 lines to: 'twitch_employees.csv'
# Wrote 119 lines to: 'twitch_employees.csv'
# Wrote 120 lines to: 'twitch_employees.csv'
# Wrote 121 lines to: 'twitch_employees.csv'
# Wrote 122 lines to: 'twitch_employees.csv'
# Wrote 123 lines to: 'twitch_employees.csv'
# Wrote 124 lines to: 'twitch_employees.csv'
# Wrote 125 lines to: 'twitch_employees.csv'
# Wrote 126 lines to: 'twitch_employees.csv'
# Wrote 127 lines to: 'twitch_employees.csv'
# Wrote 128 lines to: 'twitch_employees.csv'
# Wrote 129 lines to: 'twitch_employees.csv'
# Wrote 130 lines to: 'twitch_employees.csv'
# Wrote 131 lines to: 'twitch_employees.csv'
# Wrote 132 lines to: 'twitch_employees.csv'
# Wrote 133 lines to: 'twitch_employees.csv'
# Wrote 134 lines to: 'twitch_employees.csv'
# Wrote 135 lines to: 'twitch_employees.csv'
# Wrote 136 lines to: 'twitch_employees.csv'
# Wrote 137 lines to: 'twitch_employees.csv'
# Wrote 138 lines to: 'twitch_employees.csv'
# Wrote 139 lines to: 'twitch_employees.csv'
# Wrote 140 lines to: 'twitch_employees.csv'
# Wrote 141 lines to: 'twitch_employees.csv'
# Wrote 142 lines to: 'twitch_employees.csv'
# Wrote 143 lines to: 'twitch_employees.csv'
# Wrote 144 lines to: 'twitch_employees.csv'
# Wrote 145 lines to: 'twitch_employees.csv'
# Wrote 146 lines to: 'twitch_employees.csv'
# Wrote 147 lines to: 'twitch_employees.csv'
# Wrote 148 lines to: 'twitch_employees.csv'
# Wrote 149 lines to: 'twitch_employees.csv'
# Wrote 150 lines to: 'twitch_employees.csv'
# Wrote 151 lines to: 'twitch_employees.csv'
# Wrote 152 lines to: 'twitch_employees.csv'
# Wrote 153 lines to: 'twitch_employees.csv'
# Wrote 154 lines to: 'twitch_employees.csv'
# Wrote 155 lines to: 'twitch_employees.csv'
# Wrote 156 lines to: 'twitch_employees.csv'
# Wrote 157 lines to: 'twitch_employees.csv'
# Wrote 158 lines to: 'twitch_employees.csv'
# Wrote 159 lines to: 'twitch_employees.csv'
# Wrote 160 lines to: 'twitch_employees.csv'
# Wrote 161 lines to: 'twitch_employees.csv'
# Wrote 162 lines to: 'twitch_employees.csv'
# Wrote 163 lines to: 'twitch_employees.csv'
# Wrote 164 lines to: 'twitch_employees.csv'
# Wrote 165 lines to: 'twitch_employees.csv'
# Wrote 166 lines to: 'twitch_employees.csv'
# Wrote 167 lines to: 'twitch_employees.csv'
# Wrote 168 lines to: 'twitch_employees.csv'
# Wrote 169 lines to: 'twitch_employees.csv'
# Wrote 170 lines to: 'twitch_employees.csv'
# Wrote 171 lines to: 'twitch_employees.csv'
# Wrote 172 lines to: 'twitch_employees.csv'
# Wrote 173 lines to: 'twitch_employees.csv'
# Wrote 174 lines to: 'twitch_employees.csv'
# Wrote 175 lines to: 'twitch_employees.csv'
# Wrote 176 lines to: 'twitch_employees.csv'
# Wrote 177 lines to: 'twitch_employees.csv'
# Wrote 178 lines to: 'twitch_employees.csv'
# Wrote 179 lines to: 'twitch_employees.csv'
# Wrote 180 lines to: 'twitch_employees.csv'
# Wrote 181 lines to: 'twitch_employees.csv'
# Wrote 182 lines to: 'twitch_employees.csv'
# Wrote 183 lines to: 'twitch_employees.csv'
# Wrote 184 lines to: 'twitch_employees.csv'
# Wrote 185 lines to: 'twitch_employees.csv'
# Wrote 186 lines to: 'twitch_employees.csv'
# Wrote 187 lines to: 'twitch_employees.csv'
# Wrote 188 lines to: 'twitch_employees.csv'
# Wrote 189 lines to: 'twitch_employees.csv'
# Wrote 190 lines to: 'twitch_employees.csv'
# Wrote 191 lines to: 'twitch_employees.csv'
# Wrote 192 lines to: 'twitch_employees.csv'
# Wrote 193 lines to: 'twitch_employees.csv'
# Wrote 194 lines to: 'twitch_employees.csv'
# Wrote 195 lines to: 'twitch_employees.csv'
# Wrote 196 lines to: 'twitch_employees.csv'
# Wrote 197 lines to: 'twitch_employees.csv'
# Wrote 198 lines to: 'twitch_employees.csv'
# Wrote 199 lines to: 'twitch_employees.csv'
# Wrote 200 lines to: 'twitch_employees.csv'
# Wrote 201 lines to: 'twitch_employees.csv'
# Wrote 202 lines to: 'twitch_employees.csv'
# Wrote 203 lines to: 'twitch_employees.csv'
# Wrote 204 lines to: 'twitch_employees.csv'
# Wrote 205 lines to: 'twitch_employees.csv'
# Wrote 206 lines to: 'twitch_employees.csv'
# Wrote 207 lines to: 'twitch_employees.csv'
# Wrote 208 lines to: 'twitch_employees.csv'
# Wrote 209 lines to: 'twitch_employees.csv'
# Wrote 210 lines to: 'twitch_employees.csv'
# Wrote 211 lines to: 'twitch_employees.csv'
# Wrote 212 lines to: 'twitch_employees.csv'
# Wrote 213 lines to: 'twitch_employees.csv'
# Wrote 214 lines to: 'twitch_employees.csv'
# Wrote 215 lines to: 'twitch_employees.csv'
# Wrote 216 lines to: 'twitch_employees.csv'
# Wrote 217 lines to: 'twitch_employees.csv'
# Wrote 218 lines to: 'twitch_employees.csv'
# Wrote 219 lines to: 'twitch_employees.csv'
# Wrote 220 lines to: 'twitch_employees.csv'
# Wrote 221 lines to: 'twitch_employees.csv'
# Wrote 222 lines to: 'twitch_employees.csv'
# Wrote 223 lines to: 'twitch_employees.csv'
# Wrote 224 lines to: 'twitch_employees.csv'
# Wrote 225 lines to: 'twitch_employees.csv'
# Wrote 226 lines to: 'twitch_employees.csv'
# Wrote 227 lines to: 'twitch_employees.csv'
# Wrote 228 lines to: 'twitch_employees.csv'
# Wrote 229 lines to: 'twitch_employees.csv'
# Wrote 230 lines to: 'twitch_employees.csv'
# Wrote 231 lines to: 'twitch_employees.csv'
# Wrote 232 lines to: 'twitch_employees.csv'
# Wrote 233 lines to: 'twitch_employees.csv'
# Wrote 234 lines to: 'twitch_employees.csv'
# Wrote 235 lines to: 'twitch_employees.csv'
# Wrote 236 lines to: 'twitch_employees.csv'
# Wrote 237 lines to: 'twitch_employees.csv'
# Wrote 238 lines to: 'twitch_employees.csv'
# Wrote 239 lines to: 'twitch_employees.csv'
# Wrote 240 lines to: 'twitch_employees.csv'
# Wrote 241 lines to: 'twitch_employees.csv'
# Wrote 242 lines to: 'twitch_employees.csv'
# Wrote 243 lines to: 'twitch_employees.csv'
# Wrote 244 lines to: 'twitch_employees.csv'
# Wrote 245 lines to: 'twitch_employees.csv'
# Wrote 246 lines to: 'twitch_employees.csv'
# Wrote 247 lines to: 'twitch_employees.csv'
# Wrote 248 lines to: 'twitch_employees.csv'
# Wrote 249 lines to: 'twitch_employees.csv'
# Wrote 250 lines to: 'twitch_employees.csv'
# Wrote 251 lines to: 'twitch_employees.csv'
# Wrote 252 lines to: 'twitch_employees.csv'
# Wrote 253 lines to: 'twitch_employees.csv'
# Wrote 254 lines to: 'twitch_employees.csv'
# Wrote 255 lines to: 'twitch_employees.csv'
# Wrote 256 lines to: 'twitch_employees.csv'
# Wrote 257 lines to: 'twitch_employees.csv'
# Wrote 258 lines to: 'twitch_employees.csv'
# Wrote 259 lines to: 'twitch_employees.csv'
# Wrote 260 lines to: 'twitch_employees.csv'
# Wrote 261 lines to: 'twitch_employees.csv'
# Wrote 262 lines to: 'twitch_employees.csv'
# Wrote 263 lines to: 'twitch_employees.csv'
# Wrote 264 lines to: 'twitch_employees.csv'
# Wrote 265 lines to: 'twitch_employees.csv'
# Wrote 266 lines to: 'twitch_employees.csv'
# Wrote 267 lines to: 'twitch_employees.csv'
# Wrote 268 lines to: 'twitch_employees.csv'
# Wrote 269 lines to: 'twitch_employees.csv'
# Wrote 270 lines to: 'twitch_employees.csv'
# Wrote 271 lines to: 'twitch_employees.csv'
# Wrote 272 lines to: 'twitch_employees.csv'
# Wrote 273 lines to: 'twitch_employees.csv'
# Wrote 274 lines to: 'twitch_employees.csv'
# Wrote 275 lines to: 'twitch_employees.csv'
# Wrote 276 lines to: 'twitch_employees.csv'
# Wrote 277 lines to: 'twitch_employees.csv'
# Wrote 278 lines to: 'twitch_employees.csv'
# Wrote 279 lines to: 'twitch_employees.csv'
# Wrote 280 lines to: 'twitch_employees.csv'
# Wrote 281 lines to: 'twitch_employees.csv'
# Wrote 282 lines to: 'twitch_employees.csv'
# Wrote 283 lines to: 'twitch_employees.csv'
# Wrote 284 lines to: 'twitch_employees.csv'
# Wrote 285 lines to: 'twitch_employees.csv'
# Wrote 286 lines to: 'twitch_employees.csv'
# Wrote 287 lines to: 'twitch_employees.csv'
# Wrote 288 lines to: 'twitch_employees.csv'
# Wrote 289 lines to: 'twitch_employees.csv'
# Wrote 290 lines to: 'twitch_employees.csv'
# Wrote 291 lines to: 'twitch_employees.csv'
# Wrote 292 lines to: 'twitch_employees.csv'
# Wrote 293 lines to: 'twitch_employees.csv'
# Wrote 294 lines to: 'twitch_employees.csv'
# Wrote 295 lines to: 'twitch_employees.csv'
# Wrote 296 lines to: 'twitch_employees.csv'
# Wrote 297 lines to: 'twitch_employees.csv'
# Wrote 298 lines to: 'twitch_employees.csv'
# Wrote 299 lines to: 'twitch_employees.csv'
# Wrote 300 lines to: 'twitch_employees.csv'
# Wrote 301 lines to: 'twitch_employees.csv'
# Wrote 302 lines to: 'twitch_employees.csv'
# Wrote 303 lines to: 'twitch_employees.csv'
# Wrote 304 lines to: 'twitch_employees.csv'
# Wrote 305 lines to: 'twitch_employees.csv'
# Wrote 306 lines to: 'twitch_employees.csv'
# Wrote 307 lines to: 'twitch_employees.csv'
# Wrote 308 lines to: 'twitch_employees.csv'
# Wrote 309 lines to: 'twitch_employees.csv'
# Wrote 310 lines to: 'twitch_employees.csv'
# Wrote 311 lines to: 'twitch_employees.csv'
# Wrote 312 lines to: 'twitch_employees.csv'
# Wrote 313 lines to: 'twitch_employees.csv'
# Wrote 314 lines to: 'twitch_employees.csv'
# Wrote 315 lines to: 'twitch_employees.csv'
# Wrote 316 lines to: 'twitch_employees.csv'
# Wrote 317 lines to: 'twitch_employees.csv'
# Wrote 318 lines to: 'twitch_employees.csv'
# Wrote 319 lines to: 'twitch_employees.csv'
# Wrote 320 lines to: 'twitch_employees.csv'
# Wrote 321 lines to: 'twitch_employees.csv'
# Wrote 322 lines to: 'twitch_employees.csv'
# Wrote 323 lines to: 'twitch_employees.csv'
# Wrote 324 lines to: 'twitch_employees.csv'
# Wrote 325 lines to: 'twitch_employees.csv'
# Wrote 326 lines to: 'twitch_employees.csv'
# Wrote 327 lines to: 'twitch_employees.csv'
# Wrote 328 lines to: 'twitch_employees.csv'
# Wrote 329 lines to: 'twitch_employees.csv'
# Wrote 330 lines to: 'twitch_employees.csv'
# Wrote 331 lines to: 'twitch_employees.csv'
# Wrote 332 lines to: 'twitch_employees.csv'
# Wrote 333 lines to: 'twitch_employees.csv'
# Wrote 334 lines to: 'twitch_employees.csv'
# Wrote 335 lines to: 'twitch_employees.csv'
# Wrote 336 lines to: 'twitch_employees.csv'
# Wrote 337 lines to: 'twitch_employees.csv'
# Wrote 338 lines to: 'twitch_employees.csv'
# Wrote 339 lines to: 'twitch_employees.csv'
# Wrote 340 lines to: 'twitch_employees.csv'
# Wrote 341 lines to: 'twitch_employees.csv'
# Wrote 342 lines to: 'twitch_employees.csv'
# Wrote 343 lines to: 'twitch_employees.csv'
# Wrote 344 lines to: 'twitch_employees.csv'
# Wrote 345 lines to: 'twitch_employees.csv'
# Wrote 346 lines to: 'twitch_employees.csv'
# Wrote 347 lines to: 'twitch_employees.csv'
# Wrote 348 lines to: 'twitch_employees.csv'
# Wrote 349 lines to: 'twitch_employees.csv'
# Wrote 350 lines to: 'twitch_employees.csv'
# Wrote 351 lines to: 'twitch_employees.csv'
# Wrote 352 lines to: 'twitch_employees.csv'
# Wrote 353 lines to: 'twitch_employees.csv'
# Wrote 354 lines to: 'twitch_employees.csv'
# Wrote 355 lines to: 'twitch_employees.csv'
# Wrote 356 lines to: 'twitch_employees.csv'
# Wrote 357 lines to: 'twitch_employees.csv'
# Wrote 358 lines to: 'twitch_employees.csv'
# Wrote 359 lines to: 'twitch_employees.csv'
# Wrote 360 lines to: 'twitch_employees.csv'
# Wrote 361 lines to: 'twitch_employees.csv'
# Wrote 362 lines to: 'twitch_employees.csv'
# Wrote 363 lines to: 'twitch_employees.csv'
# Wrote 364 lines to: 'twitch_employees.csv'
# Wrote 365 lines to: 'twitch_employees.csv'
# Wrote 366 lines to: 'twitch_employees.csv'
# Wrote 367 lines to: 'twitch_employees.csv'
# Wrote 368 lines to: 'twitch_employees.csv'
# Wrote 369 lines to: 'twitch_employees.csv'
# Wrote 370 lines to: 'twitch_employees.csv'
# Wrote 371 lines to: 'twitch_employees.csv'
# Wrote 372 lines to: 'twitch_employees.csv'
# Wrote 373 lines to: 'twitch_employees.csv'
# Wrote 374 lines to: 'twitch_employees.csv'
# Wrote 375 lines to: 'twitch_employees.csv'
# Wrote 376 lines to: 'twitch_employees.csv'
# Wrote 377 lines to: 'twitch_employees.csv'
# Wrote 378 lines to: 'twitch_employees.csv'
# Wrote 379 lines to: 'twitch_employees.csv'
# Wrote 380 lines to: 'twitch_employees.csv'
# Wrote 381 lines to: 'twitch_employees.csv'
# Wrote 382 lines to: 'twitch_employees.csv'
# Wrote 383 lines to: 'twitch_employees.csv'
# Wrote 384 lines to: 'twitch_employees.csv'
# Wrote 385 lines to: 'twitch_employees.csv'
# Wrote 386 lines to: 'twitch_employees.csv'
# Wrote 387 lines to: 'twitch_employees.csv'
# Wrote 388 lines to: 'twitch_employees.csv'
# Wrote 389 lines to: 'twitch_employees.csv'
# Wrote 390 lines to: 'twitch_employees.csv'
# Wrote 391 lines to: 'twitch_employees.csv'
# Wrote 392 lines to: 'twitch_employees.csv'
# Wrote 393 lines to: 'twitch_employees.csv'
# Wrote 394 lines to: 'twitch_employees.csv'
# Wrote 395 lines to: 'twitch_employees.csv'
# Wrote 396 lines to: 'twitch_employees.csv'
# Wrote 397 lines to: 'twitch_employees.csv'
# Wrote 398 lines to: 'twitch_employees.csv'
# Wrote 399 lines to: 'twitch_employees.csv'
# Wrote 400 lines to: 'twitch_employees.csv'
# Wrote 401 lines to: 'twitch_employees.csv'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13916/2463538066.py in <module>
# ----> 1 map("a79cd2fea39460c9c8f8c66673d30a34a79c59654050e441b63268dcf28186c3", "twitch")
#
# ~\AppData\Local\Temp/ipykernel_13916/1091460351.py in map(API_KEY, company_name)
#      97     save_profiles_to_csv(all_records, csv_filename, csv_header_fields)
#      98     df = pd.read_csv(csv_filename)
# ---> 99     df['lat'] = df['location_geo'].apply(lambda s: float(s.split(',')[0]))
#     100     df['lon'] = df['location_geo'].apply(lambda s: float(s.split(',')[1]))
#     101     # used Mapbox for map with streets
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_13916/1091460351.py in <lambda>(s)
#      97     save_profiles_to_csv(all_records, csv_filename, csv_header_fields)
#      98     df = pd.read_csv(csv_filename)
# ---> 99     df['lat'] = df['location_geo'].apply(lambda s: float(s.split(',')[0]))
#     100     df['lon'] = df['location_geo'].apply(lambda s: float(s.split(',')[1]))
#     101     # used Mapbox for map with streets
#
# AttributeError: 'float' object has no attribute 'split'
