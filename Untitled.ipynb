# %% [markdown]
# The below is calling the API based on some criteria. You can edit the criteria by looking for the """EDIT HERE"""
# For the purpose of the project,

# %%
import requests

"""EDIT HERE, it's written with SQL using https://docs.peopledatalabs.com/reference/get-v5-company-search"""
url = "https://api.peopledatalabs.com/v5/company/search?sql=SELECT%20%2A%20FROM%20company%20WHERE%20employee_count%3C10000&size=100&titlecase=false&pretty=true"

headers = {
    "Content-Type": "application/json",
    "X-API-Key": "a79cd2fea39460c9c8f8c66673d30a34a79c59654050e441b63268dcf28186c3"
}

response = requests.request("GET", url, headers=headers)

print(response.text)
#outputs a string
# Out:
# {
#   "status": 200,
#   "data": [
#     {
#       "name": "stanbic bank",
#       "size": "10001+",
#       "employee_count": 5656,
#       "id": "stanbic-bank",
#       "founded": 1862,
#       "industry": "banking",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "united states",
#         "locality": null,
#         "region": null,
#         "metro": null,
#         "country": "united states",
#         "continent": "north america",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": null
#       },
#       "linkedin_id": "70939",
#       "linkedin_url": "linkedin.com/company/stanbic-bank",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/stanbic-bank",
#         "linkedin.com/company/70939"
#       ],
#       "website": null,
#       "ticker": null,
#       "type": "private",
#       "summary": "standard bank group operates as stanbic bank in some countries in africa. standard bank group has a 152-year history in africa.\n\n we currently operate in 20 countries on the african continent as well as in other selected emerging markets. you will also find standard bank group in 12 countries outside of africa.\n\n our strategy is to build the leading african financial services organisation using all our competitive advantages to the full.\n\n at standard bank group we focus on connecting other selected emerging markets to africa and to each other, applying our sector expertise, particularly in natural resources, globally. our key differentiator is people who are passionate about our strategy, wherever in the world they are based.\n\n we organise ourselves as three business units but present ourselves as one. our three main pillars of business are personal & business banking, corporate & investment banking, and wealth creation.",
#       "tags": [
#         "corporate banking",
#         "institutional banking",
#         "wealth creation",
#         "business banking",
#         "personal banking"
#       ],
#       "headline": "We have a presence in various countries. Kindly search for Stanbic Bank in your country and follow that company page.",
#       "alternative_names": [
#         "stanbic bank zambia",
#         "stanbic bank tanzania",
#         "stanbic bank uganda",
#         "stanbic bank botswana",
#         "stanbic ibtc bank",
#         "stanbic bank zambia limited",
#         "cfc stanbic bank",
#         "stanbic ibtc bank plc",
#         "stanbic bank uganda limited",
#         "stanbic bank zimbabwe"
#       ],
#       "affiliated_profiles": [
#         "standard-bank-group",
#         "stanbic-bank-uganda"
#       ]
#     },
#     {
#       "name": "vaardam",
#       "size": "10001+",
#       "employee_count": 0,
#       "id": "vaardam",
#       "founded": 2018,
#       "industry": "non-profit organization management",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "lunteren, gelderland, netherlands",
#         "locality": "lunteren",
#         "region": "gelderland",
#         "metro": null,
#         "country": "netherlands",
#         "continent": "europe",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": "52.08,5.62"
#       },
#       "linkedin_id": "12624348",
#       "linkedin_url": "linkedin.com/company/vaardam",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/vaardam",
#         "linkedin.com/company/12624348"
#       ],
#       "website": "vaardam.nl",
#       "ticker": null,
#       "type": "nonprofit",
#       "summary": "vaardam is de eerste virtuele gemeente van nederland ontstaan vanuit de co-creatie tussen marktpartijen en gemeenten. opgezet om maatschappelijke problemen op te lossen m.b.v. technologische oplossingen. het is een transparant ecosysteem waar de publieke (gemeenten en ketenpartners) en private sector de klassieke rollen achter zich laten om samen te bouwen aan de toekomst van nederland.  help mee om de overheid van de toekomst handen en voeten te geven",
#       "tags": null,
#       "headline": "De eerste virtuele gemeente van Nederland opgezet door marktpartijen en gemeenten om maatschappelijke impact te maken",
#       "alternative_names": [],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "looking for a job",
#       "size": "10001+",
#       "employee_count": 2,
#       "id": "looking-for-a-job123",
#       "founded": null,
#       "industry": "civil engineering",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "indiana, united states",
#         "locality": null,
#         "region": "indiana",
#         "metro": null,
#         "country": "united states",
#         "continent": "north america",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": null
#       },
#       "linkedin_id": "14387267",
#       "linkedin_url": "linkedin.com/company/looking-for-a-job123",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/looking-for-a-job123",
#         "linkedin.com/company/14387267"
#       ],
#       "website": null,
#       "ticker": null,
#       "type": "private",
#       "summary": "\u201cyou don\u2019t have to be great to start, but you so have to start to be great.\u201d - zig ziglar\n\u201cthe difference between a dream and a goal is a deadline\u201d \u2013 steve smith\n\u201cnobody can go back and start a new beginning, but anyone can start today and make a new ending.\u201d ~ maria robinson\n\u201cif everybody\u2019s thinking alike, then somebody\u2019s not thinking.\u201d - george s. patton\n\u201cif your ship doesn\u2019t come in, swim out to meet it\u201d \u2013 jonathan winters\n\u201cthe world is round, and the place which may seem like the end may also be only the beginning\u201d \u2013 ivy baker priest\n\u201cdon\u2019t fall before you\u2019re pushed\u201d \u2013 english proverb\n\u201cthe time to repair the roof is when the sun is shining\u201d - john f kennedy\n\u201cpositive things happen to positive people.\u201d - sarah beeny\n\u201cif you want the rainbow, you gotta put up with the rain.\u201d - dolly parton\n\u201cit is never too late to be what you might have been.\u201d - george elliot\n\u201cthings do not happen. things are made to happen.\u201d - john f kennedy\n\u201cyou are never too old to set another goal or to dream a n",
#       "tags": null,
#       "headline": null,
#       "alternative_names": [
#         "orator hotel",
#         "jm montagens e instala\u00e7\u00f5es industriais",
#         "power for special construction",
#         "self employed",
#         "label engineering sdn. bhd.",
#         "hi tect architects"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "home depot/your other warehouse",
#       "size": "10001+",
#       "employee_count": 2708,
#       "id": "home-depot-your-other-warehouse",
#       "founded": null,
#       "industry": "retail",
#       "naics": [
#         {
#           "naics_code": "42399",
#           "sector": "wholesale trade",
#           "sub_sector": "merchant wholesalers, durable goods",
#           "industry_group": "miscellaneous durable goods merchant wholesalers",
#           "national_industry": null
#         }
#       ],
#       "sic": [
#         {
#           "sic_code": "5099",
#           "major_group": "wholesale trade-durable goods",
#           "industry_group": "miscellaneous durable goods",
#           "industry_sector": "durable goods, not elsewhere classified"
#         }
#       ],
#       "location": {
#         "name": "louisiana, united states",
#         "locality": null,
#         "region": "louisiana",
#         "metro": null,
#         "country": "united states",
#         "continent": "north america",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": null
#       },
#       "linkedin_id": "291968",
#       "linkedin_url": "linkedin.com/company/home-depot-your-other-warehouse",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/home-depot-your-other-warehouse",
#         "linkedin.com/company/291968"
#       ],
#       "website": "yourotherwarehouse.com",
#       "ticker": null,
#       "type": "private",
#       "summary": "home improvement retailer/wholesaler",
#       "tags": null,
#       "headline": null,
#       "alternative_names": [
#         "home depot",
#         "your \"other\" warehouse",
#         "the home depot",
#         "your other warehouse",
#         "your other warehouse/ home depot direct",
#         "warehouse associate | scp | april",
#         "uyghur canadian society",
#         "de quartier",
#         "amnistie internationale francophone universit\u00e9 de montr\u00e9al",
#         "retired"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "modelsownit 4444",
#       "size": "10001+",
#       "employee_count": 10,
#       "id": "modelsownit",
#       "founded": 2016,
#       "industry": "cosmetics",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "amsterdam, noord-holland, netherlands",
#         "locality": "amsterdam",
#         "region": "noord-holland",
#         "metro": null,
#         "country": "netherlands",
#         "continent": "europe",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": "52.35,4.91"
#       },
#       "linkedin_id": null,
#       "linkedin_url": "linkedin.com/company/modelsownit",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/modelsownit"
#       ],
#       "website": null,
#       "ticker": null,
#       "type": "private",
#       "summary": "retailer and producter of make up.\ncontains valuble magnetics such as gold, glitter, diamonds and crushed crystal stones.fruit, trees and vegetables. non-pgmo.",
#       "tags": [
#         "beauty.",
#         "acczezoriez.",
#         "make-up."
#       ],
#       "headline": null,
#       "alternative_names": [],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "ii-vi incorporated",
#       "size": "10001+",
#       "employee_count": 1882,
#       "id": "ii-vi-incorporated",
#       "founded": 1971,
#       "industry": "defense & space",
#       "naics": [
#         {
#           "naics_code": "335",
#           "sector": "manufacturing",
#           "sub_sector": "electrical equipment, appliance, and component manufacturing",
#           "industry_group": null,
#           "national_industry": null
#         },
#         {
#           "naics_code": "333314",
#           "sector": "manufacturing",
#           "sub_sector": "machinery manufacturing",
#           "industry_group": "commercial and service industry machinery manufacturing",
#           "national_industry": "optical instrument and lens manufacturing"
#         }
#       ],
#       "sic": [
#         {
#           "sic_code": "3827",
#           "major_group": "measuring, analyzing, and controlling instruments; photographic, medical and optical goods; watches and clocks",
#           "industry_group": "laboratory apparatus and analytical, optical, measuring, and controlling instruments",
#           "industry_sector": "optical instruments and lenses"
#         }
#       ],
#       "location": {
#         "name": "saxonburg, pennsylvania, united states",
#         "locality": "saxonburg",
#         "region": "pennsylvania",
#         "metro": "pittsburgh, pennsylvania",
#         "country": "united states",
#         "continent": "north america",
#         "street_address": "375 saxonburg boulevard",
#         "address_line_2": null,
#         "postal_code": "16056",
#         "geo": "40.75,-79.81"
#       },
#       "linkedin_id": "74708",
#       "linkedin_url": "linkedin.com/company/ii-vi-incorporated",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/ii-vi-incorporated",
#         "linkedin.com/company/74708",
#         "crunchbase.com/organization/ii-vi"
#       ],
#       "website": "ii-vi.com",
#       "ticker": null,
#       "type": "private",
#       "summary": "ii-vi incorporated, a global leader in engineered materials and optoelectronic devices and components, is a vertically integrated manufacturing company that develops innovative products for diversified applications in the industrial, optical communications, military, life sciences, semiconductor equipment and consumer markets. headquartered in saxonburg, pennsylvania, with research and development, manufacturing, sales, service and distribution facilities worldwide, the company produces a wide variety of application-specific photonic and electronic materials and components and deploys them in various forms, including integrated with advanced software, to enable our customers\u2019 success.",
#       "tags": [
#         "engineered materials enabling optics",
#         "photonics and electronics for advanced devices and systems",
#         "infrared optics",
#         "synthetic crystal materials growth",
#         "electronics component manufacture",
#         "optics fabrication",
#         "near infrared optics",
#         "optic materials",
#         "onics and electronics for advanced devices and systems"
#       ],
#       "headline": "II-VI Incorporated is a global leader in engineered materials and optoelectronic components. https://twitter.com/iiviinc",
#       "alternative_names": [
#         "ii-vi",
#         "ii-vi laser enterprise",
#         "ii-vi laser enterprise gmbh",
#         "ii-vi inc.",
#         "ii-vi inc",
#         "ii-vi photonics",
#         "ii-vi laser enterprise gmbh / ii-vi incorporated",
#         "ii-vi japan incorporated",
#         "ii-vi laser enterprise gmbh/ii-vi incorporated",
#         "ii-vi optical systems"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "esbjerg kommune",
#       "size": "10001+",
#       "employee_count": 2199,
#       "id": "esbjerg-kommune",
#       "founded": 2007,
#       "industry": "civic & social organization",
#       "naics": [
#         {
#           "naics_code": "61",
#           "sector": "educational services",
#           "sub_sector": null,
#           "industry_group": null,
#           "national_industry": null
#         },
#         {
#           "naics_code": "813",
#           "sector": "other services (except public administration)",
#           "sub_sector": "religious, grantmaking, civic, professional, and similar organizations",
#           "industry_group": null,
#           "national_industry": null
#         },
#         {
#           "naics_code": "71",
#           "sector": "arts, entertainment, and recreation",
#           "sub_sector": null,
#           "industry_group": null,
#           "national_industry": null
#         }
#       ],
#       "sic": [
#         {
#           "sic_code": "4899",
#           "major_group": "communications",
#           "industry_group": "communications services, not elsewhere",
#           "industry_sector": "communications services, not elsewhere classified"
#         },
#         {
#           "sic_code": "5812",
#           "major_group": "eating and drinking places",
#           "industry_group": "eating and drinking places",
#           "industry_sector": "eating places"
#         },
#         {
#           "sic_code": "7991",
#           "major_group": "amusement and recreation services",
#           "industry_group": "miscellaneous amusement and recreation",
#           "industry_sector": "physical fitness facilities"
#         }
#       ],
#       "location": {
#         "name": "esbjerg, syddanmark, denmark",
#         "locality": "esbjerg",
#         "region": "syddanmark",
#         "metro": null,
#         "country": "denmark",
#         "continent": "europe",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": "55.47,8.45"
#       },
#       "linkedin_id": "44142",
#       "linkedin_url": "linkedin.com/company/esbjerg-kommune",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/esbjerg-kommune",
#         "linkedin.com/company/44142"
#       ],
#       "website": "esbjergkommune.dk",
#       "ticker": null,
#       "type": "private",
#       "summary": "2",
#       "tags": null,
#       "headline": "Energi til mere.",
#       "alternative_names": [
#         "esbjerg kommunes biblioteker",
#         "esbjerg municipality",
#         "municipality of esbjerg",
#         "jobcenter esbjerg",
#         "home esbjerg",
#         "projekt & udvikling, sundhedsafdelingen, esbjerg kommune",
#         "esbjerg kommune ssp & forebyggelse",
#         "esbjerg airport",
#         "esbjerg kommune, teknik & milj\u00f8",
#         "morgenr\u00f8den esbjerg kommune"
#       ],
#       "affiliated_profiles": [
#         "jobannoncer---esbjerg-kommune",
#         "esbjerg-kommune---udbud-&-indk%C3%B8b"
#       ]
#     },
#     {
#       "name": "googol power bangladesh",
#       "size": "10001+",
#       "employee_count": 2,
#       "id": "infinitybdltd",
#       "founded": null,
#       "industry": "machinery",
#       "naics": [
#         {
#           "naics_code": "54199",
#           "sector": "professional, scientific, and technical services",
#           "sub_sector": "professional, scientific, and technical services",
#           "industry_group": "other professional, scientific, and technical services",
#           "national_industry": null
#         }
#       ],
#       "sic": [
#         {
#           "sic_code": "7299",
#           "major_group": "personal services",
#           "industry_group": "miscellaneous personal services",
#           "industry_sector": "miscellaneous personal services, not elsewhere classified"
#         }
#       ],
#       "location": {
#         "name": "dhaka, bangladesh",
#         "locality": null,
#         "region": "dhaka",
#         "metro": null,
#         "country": "bangladesh",
#         "continent": "asia",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": null
#       },
#       "linkedin_id": "13322031",
#       "linkedin_url": "linkedin.com/company/infinitybdltd",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/infinitybdltd",
#         "linkedin.com/company/13322031"
#       ],
#       "website": "googolengine.com",
#       "ticker": null,
#       "type": "private",
#       "summary": "scope of supply: \u2022 diesel generator (20kw-2800kw) \u2022 silent , mobile & container generator (20kw-2800kw) \u2022 dual fuel generator (160kw-2400kw) \u2022 nature gas generator (160kw-1800kw) \u2022 marine generator (80kw-2000kw) \u2022 pump generator (20kw-2800kw) \u2022 ac alternator (20kw-5mw) \u2022 high voltage generators (500kw-2800kw) \u2022 middle speed generators (1000rpm,1200rpm) \u2022 diesel power plant (2mw-200mw) \u2022 gas power plant (1mw-200mw) \u2022 hfo power plant (2mw-200mw) \u2022 distributed energy chp cchp (2mw-200mw) \u2022 spare parts & service.",
#       "tags": null,
#       "headline": null,
#       "alternative_names": [
#         "infinity bd ltd",
#         "chongqing googol engine-tech co., ltd"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "securitas security services inc., sseu division",
#       "size": "10001+",
#       "employee_count": 1,
#       "id": "securitas-security-services-inc-sseu-division",
#       "founded": null,
#       "industry": "security and investigations",
#       "naics": null,
#       "sic": null,
#       "location": null,
#       "linkedin_id": null,
#       "linkedin_url": "linkedin.com/company/securitas-security-services-inc-sseu-division",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/securitas-security-services-inc-sseu-division"
#       ],
#       "website": null,
#       "ticker": null,
#       "type": "private",
#       "summary": null,
#       "tags": null,
#       "headline": null,
#       "alternative_names": [],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "air france klm martinair cargo",
#       "size": "10001+",
#       "employee_count": 332,
#       "id": "afklmpcargo",
#       "founded": null,
#       "industry": "airlines/aviation",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "ee, friesland, netherlands",
#         "locality": "ee",
#         "region": "friesland",
#         "metro": null,
#         "country": "netherlands",
#         "continent": "europe",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": "53.33,6.10"
#       },
#       "linkedin_id": null,
#       "linkedin_url": "linkedin.com/company/afklmpcargo",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/afklmpcargo"
#       ],
#       "website": "afklcargo.com",
#       "ticker": null,
#       "type": "private",
#       "summary": "air france klm martinair cargo is the dedicated air cargo business of the air france klm group. by joining forces in the cargo arena in 2005, afklmp cargo is today a key player in the air cargo industry. \n\nhistorically, air france cargo, klm cargo and martinair cargo have always been at the forefront of transporting and handling a variety of cargo. building on this experience, air france klm martinair cargo offers a wide range of air transport services in the market, providing seamless connections throughout the world, with more than 450 destinations in 158 countries. through the combined fleet of our three airlines, we transport a wide variety of goods to all corners of the globe with 174 aircrafts. we transported 1.13 million tonnes for a total of 2.1 billion revenue in 2016.\n\nour two hubs, paris charles de gaulle and amsterdam airport schiphol, are ideally located to allow for flexibility in reaching your final destination. more than ever, we are committed to quality and simplicity ",
#       "tags": null,
#       "headline": null,
#       "alternative_names": [
#         "air france klm martinair cargo",
#         "air france - klm cargo",
#         "air france cargo",
#         "air france - klm",
#         "air france - klm - martinair cargo",
#         "air france-klm-martinair cargo",
#         "air france cargo / quantem aviation (aci)",
#         "air france cargo - klm cargo",
#         "martinair cargo",
#         "air france klm"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "isbpc",
#       "size": "10001+",
#       "employee_count": 2,
#       "id": "isbp-group",
#       "founded": null,
#       "industry": "international trade and development",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "phnom penh, phnom penh, cambodia",
#         "locality": "phnom penh",
#         "region": "phnom penh",
#         "metro": null,
#         "country": "cambodia",
#         "continent": "asia",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": "11.55,104.91"
#       },
#       "linkedin_id": "18932091",
#       "linkedin_url": "linkedin.com/company/isbp-group",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/isbp-group",
#         "linkedin.com/company/18932091"
#       ],
#       "website": "isbpgroup.com",
#       "ticker": null,
#       "type": "private",
#       "summary": null,
#       "tags": null,
#       "headline": "International Standard Business Plan Community",
#       "alternative_names": [
#         "isbp group"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "mylikies",
#       "size": "10001+",
#       "employee_count": 2,
#       "id": "mylikies",
#       "founded": 2019,
#       "industry": "online media",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "huizen, north holland, netherlands",
#         "locality": "huizen",
#         "region": "north holland",
#         "metro": null,
#         "country": "netherlands",
#         "continent": "europe",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": "52.29,5.24"
#       },
#       "linkedin_id": "35584523",
#       "linkedin_url": "linkedin.com/company/mylikies",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/mylikies",
#         "linkedin.com/company/35584523"
#       ],
#       "website": null,
#       "ticker": null,
#       "type": "private",
#       "summary": "mylikies is wereldwijd uniek en veel meer dan een app voor kortingen, acties en leuke events. met mylikies verdien je namelijk samen geld!\n\nmet geavanceerde app-technologie en de rings of mylikies bouw je vanzelf aan een grote community van deelnemers en adverteerders. zodra je de app deelt met jouw vrienden kun je de groei van jouw community niet meer stoppen!\n\ndat kunnen wereldwijd tienduizenden deelnemers worden. hoe groter jouw community, des te meer geld je verdient.\n\nhave fun - make money - together",
#       "tags": null,
#       "headline": "Have Fun - Make Money - Together",
#       "alternative_names": [],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "school of information technology at the university of cincinnati",
#       "size": "10001+",
#       "employee_count": 11,
#       "id": "uc-school-of-information-technology",
#       "founded": null,
#       "industry": "higher education",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "cincinnati, ohio, united states",
#         "locality": "cincinnati",
#         "region": "ohio",
#         "metro": "cincinnati, ohio",
#         "country": "united states",
#         "continent": "north america",
#         "street_address": "2610 mcmicken circle",
#         "address_line_2": null,
#         "postal_code": "45221",
#         "geo": "39.12,-84.51"
#       },
#       "linkedin_id": null,
#       "linkedin_url": "linkedin.com/company/uc-school-of-information-technology",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/uc-school-of-information-technology"
#       ],
#       "website": null,
#       "ticker": null,
#       "type": "educational",
#       "summary": "the school of information technology at the university of cincinnati offers a variety of programs: undergraduate, graduate, accelerated graduate combinations, minor, and certificates. we strive to maintain an innovative, welcoming and supportive community with many great opportunities thanks to our dedicated faculty, staff, students, alumni and friends!",
#       "tags": null,
#       "headline": "Collaborate I Innovate I Apply\nExperience+",
#       "alternative_names": [
#         "uc information technology solutions center",
#         "university of cincinnati school of information technology",
#         "university of cincinnati it",
#         "uc school of information technology"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "surecare franchising",
#       "size": "10001+",
#       "employee_count": 2,
#       "id": "surecare-franchising",
#       "founded": 1994,
#       "industry": "hospital & health care",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "chester, cheshire, united kingdom",
#         "locality": "chester",
#         "region": "cheshire",
#         "metro": null,
#         "country": "united kingdom",
#         "continent": "europe",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": null
#       },
#       "linkedin_id": "18363922",
#       "linkedin_url": "linkedin.com/company/surecare-franchising",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/surecare-franchising",
#         "linkedin.com/company/18363922"
#       ],
#       "website": "surecarefranchise.co.uk",
#       "ticker": null,
#       "type": "private",
#       "summary": "at surecare, we remain committed to providing exceptional care services in local communities across the uk.\n\nsince 1994, our care services have expanded across the country. with help from small business owners like you, we\u2019ve been able to provide a comprehensive range of care services to those in need of home support.\n\nwe cover various aspects of the care industry, from everyday personal home care support to assisting those with 24 hour complex care needs. we\u2019re committed to looking after people in all stages of life\u2019s journey, from babies and young children to the elderly, as well as those with varying disabilities. surecare franchises across the country strive to go above and beyond to provide care and support where it\u2019s most needed.\n\nsurecare is fully regulated by the care quality commission (cqc) and all of our staff are subject to enhanced disclosure and barring service (dbs) clearance. this way, we ensure that your clients receive only the best quality care, delivered to the high",
#       "tags": [
#         "care and franchising"
#       ],
#       "headline": null,
#       "alternative_names": [
#         "surecare trading as best care harrow limited"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "blue clover studios",
#       "size": "10001+",
#       "employee_count": 0,
#       "id": "blue-clover-studios",
#       "founded": 2005,
#       "industry": "packaging and containers",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "evansville, indiana, united states",
#         "locality": "evansville",
#         "region": "indiana",
#         "metro": "evansville, indiana",
#         "country": "united states",
#         "continent": "north america",
#         "street_address": "101 oakley street",
#         "address_line_2": null,
#         "postal_code": "47710",
#         "geo": "37.97,-87.55"
#       },
#       "linkedin_id": "64609610",
#       "linkedin_url": "linkedin.com/company/blue-clover-studios",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/blue-clover-studios",
#         "linkedin.com/company/64609610"
#       ],
#       "website": "studioblueclover.com",
#       "ticker": null,
#       "type": "private",
#       "summary": "we provide global package design services for the world's leading brands.",
#       "tags": [
#         "user centered design",
#         "rapid prototyping",
#         "design for manufacturing",
#         "industrial design",
#         "ideation"
#       ],
#       "headline": "As Berry Global's internal industrial design studio, we elevate the world\u2019s leading brands through package design.",
#       "alternative_names": [],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "agenda tour vietnam co.,ltd",
#       "size": "10001+",
#       "employee_count": 5,
#       "id": "agenda-tour-vietnam-co-ltd",
#       "founded": 2010,
#       "industry": "information services",
#       "naics": null,
#       "sic": null,
#       "location": null,
#       "linkedin_id": "4793750",
#       "linkedin_url": "linkedin.com/company/agenda-tour-vietnam-co-ltd",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/agenda-tour-vietnam-co-ltd",
#         "linkedin.com/company/4793750"
#       ],
#       "website": "circuitvietnam.com",
#       "ticker": null,
#       "type": "private",
#       "summary": "agence de voyage francophone bas\u00e9e \u00e0 hanoi - vietnam\n\nagenda tour est une agence de voyage locale bas\u00e9e \u00e0 hanoi - vietnam. depuis sa fondation, l\u2019agence s\u2019est sp\u00e9cialis\u00e9e dans la cr\u00e9ation de voyages en d\u00e9couverte des beaux sites, riches, vari\u00e9s, ax\u00e9s sur la culture, les paysages et les rencontres avec la population locale.",
#       "tags": null,
#       "headline": "Cr\u00e9ateur de voyages Intimes Vietnam - Laos - Cambodge - Birmanie",
#       "alternative_names": [
#         "agenda tour vietnam"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "arrows technologies",
#       "size": "10001+",
#       "employee_count": 1,
#       "id": "arrows-technologies",
#       "founded": 2008,
#       "industry": "computer software",
#       "naics": [
#         {
#           "naics_code": "5112",
#           "sector": "information",
#           "sub_sector": "publishing industries (except internet)",
#           "industry_group": "software publishers",
#           "national_industry": null
#         }
#       ],
#       "sic": [
#         {
#           "sic_code": "7372",
#           "major_group": "business services",
#           "industry_group": "computer programming, data processing, and other computer related services",
#           "industry_sector": "prepackaged software"
#         }
#       ],
#       "location": null,
#       "linkedin_id": "3310503",
#       "linkedin_url": "linkedin.com/company/arrows-technologies",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/arrows-technologies",
#         "linkedin.com/company/3310503"
#       ],
#       "website": "arrowstechno.com",
#       "ticker": null,
#       "type": "private",
#       "summary": "** arrows technologies ** accelerated deliveries through technological innovations and synchronized solutions for challenging demands. arrows are committed to build excellent customer support and beneficial partnership. arrows has been working in the field of software development, application development, product development and web design & development since 2008.",
#       "tags": [
#         "webdesign and development",
#         "software development",
#         "product development",
#         "application development"
#       ],
#       "headline": null,
#       "alternative_names": [],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "bahlol for internation shipping.bls",
#       "size": "10001+",
#       "employee_count": 3,
#       "id": "bahlol-for-internation-shipping-bls",
#       "founded": 2009,
#       "industry": "package/freight delivery",
#       "naics": null,
#       "sic": null,
#       "location": null,
#       "linkedin_id": "37519984",
#       "linkedin_url": "linkedin.com/company/bahlol-for-internation-shipping-bls",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/bahlol-for-internation-shipping-bls",
#         "linkedin.com/company/37519984"
#       ],
#       "website": "12020.tel",
#       "ticker": null,
#       "type": "private",
#       "summary": "http://www.bahlollogistics.com",
#       "tags": null,
#       "headline": "\u0634\u0631\u0643\u0647 \u0628\u0647\u0644\u0648\u0644 \u0644\u0644\u0634\u062d\u0646 \u0627\u0644\u062f\u0648\u0644\u064a\n\u062a\u062d\u0631\u0635 \u0639\u0644\u0649 \u0627\u0644\u062a\u0645\u064a\u064a\u0632 \u0641\u0649 \u0627\u0644\u0633\u0631\u0639\u0647 \u0648\u0627\u0644\u062f\u0642\u0647 \u0641\u064a \u0627\u0644\u0648\u0642\u062a \u0648\u062a\u0627\u0645\u064a\u0646 \u0627\u0644\u0628\u0636\u0627\u0626\u0639 \u0628\u0627\u0642\u0644 \u0627\u0644\u062a\u0643\u0627\u0644\u064a\u0641",
#       "alternative_names": [],
#       "affiliated_profiles": [
#         "bahlol-for-internation-shipping"
#       ]
#     },
#     {
#       "name": "shenzhen inovance technolo-a",
#       "size": "10001+",
#       "employee_count": 28,
#       "id": "\u82cf\u5dde\u6c47\u5ddd\u6280\u672f\u6709\u9650\u516c\u53f8",
#       "founded": 2003,
#       "industry": "industrial automation",
#       "naics": [
#         {
#           "naics_code": "333",
#           "sector": "manufacturing",
#           "sub_sector": "machinery manufacturing",
#           "industry_group": null,
#           "national_industry": null
#         }
#       ],
#       "sic": [
#         {
#           "sic_code": "3599",
#           "major_group": "industrial and commercial machinery and computer equipment",
#           "industry_group": "miscellaneous industrial and commercial",
#           "industry_sector": "industrial and commercial machinery and equipment, not elsewhere classified"
#         }
#       ],
#       "location": null,
#       "linkedin_id": "29212916",
#       "linkedin_url": "linkedin.com/company/\u82cf\u5dde\u6c47\u5ddd\u6280\u672f\u6709\u9650\u516c\u53f8",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/\u82cf\u5dde\u6c47\u5ddd\u6280\u672f\u6709\u9650\u516c\u53f8",
#         "linkedin.com/company/29212916"
#       ],
#       "website": "inovance.cn",
#       "ticker": null,
#       "type": "private",
#       "summary": "\u6df1\u5733\u5e02\u6c47\u5ddd\u6280\u672f\u80a1\u4efd\u6709\u9650\u516c\u53f8\u4e13\u6ce8\u4e8e\u5de5\u4e1a\u81ea\u52a8\u5316\u63a7\u5236\u4ea7\u54c1\u7684\u7814\u53d1\u3001\u751f\u4ea7\u548c\u9500\u552e\uff0c\u5b9a\u4f4d\u670d\u52a1\u4e8e\u4e2d\u9ad8\u7aef\u8bbe\u5907\u5236\u9020\u5546\uff0c\u4ee5\u62e5\u6709\u81ea\u4e3b\u77e5\u8bc6\u4ea7\u6743\u7684\u5de5\u4e1a\u81ea\u52a8\u5316\u6280\u672f\u4e3a\u57fa\u7840\uff0c\u5728\u7ecf\u8425\u8fc7\u7a0b\u4e2d\u575a\u6301\u8fdb\u53e3\u66ff\u4ee3\u3001\u884c\u4e1a\u8425\u9500\u3001\u4e3a\u7ec6\u5206\u5e02\u573a\u5ba2\u6237\u63d0\u4f9b\u6574\u4f53\u89e3\u51b3\u65b9\u6848\u7684\u7ecf\u8425\u6a21\u5f0f\uff0c\u5b9e\u73b0\u4f01\u4e1a\u4ef7\u503c\u4e0e\u5ba2\u6237\u4ef7\u503c\u5171\u540c\u6210\u957f\u3002",
#       "tags": null,
#       "headline": "\u4ee5\u9886\u5148\u6280\u672f\u63a8\u52a8\u5de5\u4e1a\u6587\u660e",
#       "alternative_names": [],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "bukit gambang resort city",
#       "size": "10001+",
#       "employee_count": 66,
#       "id": "bukit-gambang-resort-city",
#       "founded": 2009,
#       "industry": "leisure, travel & tourism",
#       "naics": [
#         {
#           "naics_code": "7139",
#           "sector": "arts, entertainment, and recreation",
#           "sub_sector": "amusement, gambling, and recreation industries",
#           "industry_group": "other amusement and recreation industries",
#           "national_industry": null
#         }
#       ],
#       "sic": null,
#       "location": {
#         "name": "kuantan, pahang, malaysia",
#         "locality": "kuantan",
#         "region": "pahang",
#         "metro": null,
#         "country": "malaysia",
#         "continent": "asia",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": "3.80,103.32"
#       },
#       "linkedin_id": "13383573",
#       "linkedin_url": "linkedin.com/company/bukit-gambang-resort-city",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/bukit-gambang-resort-city",
#         "linkedin.com/company/13383573"
#       ],
#       "website": "bgrc.com.my",
#       "ticker": null,
#       "type": "private",
#       "summary": "bukit gambang resort city (bgrc) is an integrated resort city sprawling across 727 acres of secondary jungle. strategically located in gambang, pahang, it is the gateway to the east coast of peninsular malaysia and the capital city of pahang \u2013 kuantan. bgrc is also nestled amongst the many natural and cultural attractions eagerly sought for by tourists locally or from abroad. with easy access via the east coast expressway, bgrc is a mere 218km from kuala lumpur and just 35km before the famous beach town of kuantan. by air to kuantan, the flight to sultan ahmad shah airport is approximately 40 minutes from kuala lumpur international airport (klia), 90 minutes from penang international airport and 65 minutes from singapore changi airport. bgrc is just a 35 minutes scenic drive away from the airport. developed with the concept of \u201cone location multiple attractions\u201d, bgrc offers various accommodations with integrated facilities perfect for leisure or for m.i.c.e. apart from being the home ",
#       "tags": [
#         "tourism",
#         "resort",
#         "recreational",
#         "water park",
#         "education",
#         "hospitality",
#         "m.i.c.e",
#         "entertainment",
#         "safari park",
#         "leisure"
#       ],
#       "headline": null,
#       "alternative_names": [
#         "sentoria themeparks & resorts sdn bhd"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "hindalco specialty alumina chemicals",
#       "size": "10001+",
#       "employee_count": 29,
#       "id": "hindalco-specialty-alumina-chemicals",
#       "founded": 1969,
#       "industry": "chemicals",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "mumbai, maharashtra, india",
#         "locality": "mumbai",
#         "region": "maharashtra",
#         "metro": null,
#         "country": "india",
#         "continent": "asia",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": "19.07,72.88"
#       },
#       "linkedin_id": "53184771",
#       "linkedin_url": "linkedin.com/company/hindalco-specialty-alumina-chemicals",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/hindalco-specialty-alumina-chemicals",
#         "linkedin.com/company/53184771"
#       ],
#       "website": null,
#       "ticker": null,
#       "type": "private",
#       "summary": "hindalco chemicals manufactures specialty alumina and alumina hydrate (ath) which are products of in-house technological innovation by our research & development team at hindalco innovation centre-alumina (hic-a). this research centre is recognized by the department of scientific & industrial research (dsir), government of india.\n\nthe chemicals business serves a wide range of customers across 32 countries around the world with special alumina and alumina hydrates. alumina hydrates find use in applications like \u2013 alum, poly aluminium chloride (pac), zeolites, aluminium fluoride, and as fire-retardant filler in polymer composites. our special alumina finds a good suit in applications like refractory, ceramics, polishing compounds, abrasives and glass.\n\nhindalco\u2019s captive bauxite mines in the indian states of maharashtra, jharkhand, chhattisgarh, and odisha, supply high quality raw material to our refineries located at belagavi in karnataka, muri in jharkhand and renukoot in uttar pradesh",
#       "tags": null,
#       "headline": "We manufacture materials that makes the world Greener, Stronger and Smarter. Manufacturer of Specialty Alumina & Hydrate",
#       "alternative_names": [],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "oscar mayer foods",
#       "size": "10001+",
#       "employee_count": 67,
#       "id": "oscar-mayer-foods",
#       "founded": 1883,
#       "industry": "food production",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "madison, wisconsin, united states",
#         "locality": "madison",
#         "region": "wisconsin",
#         "metro": "madison, wisconsin",
#         "country": "united states",
#         "continent": "north america",
#         "street_address": "2099 roth street",
#         "address_line_2": null,
#         "postal_code": "53704",
#         "geo": "43.07,-89.40"
#       },
#       "linkedin_id": "28121567",
#       "linkedin_url": "linkedin.com/company/oscar-mayer-foods",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/oscar-mayer-foods",
#         "linkedin.com/company/28121567"
#       ],
#       "website": null,
#       "ticker": null,
#       "type": "private",
#       "summary": "founded in 1883. the oscar mayer company is an american meat and cold cut production company, owned by the american food company kraft heinz. it is known for its hot dogs, bologna, bacon, ham and lunchables products.",
#       "tags": null,
#       "headline": null,
#       "alternative_names": [
#         "plumrose latinoamericana c.a.",
#         "oscar mayer wienermobile program",
#         "kraft foods/oscar mayer"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "partido unidad social cristiana",
#       "size": "10001+",
#       "employee_count": 7,
#       "id": "partido-unidad-social-cristiana",
#       "founded": 1983,
#       "industry": "public policy",
#       "naics": null,
#       "sic": null,
#       "location": null,
#       "linkedin_id": "4827526",
#       "linkedin_url": "linkedin.com/company/partido-unidad-social-cristiana",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/partido-unidad-social-cristiana",
#         "linkedin.com/company/4827526"
#       ],
#       "website": "pusc.cr",
#       "ticker": null,
#       "type": "private",
#       "summary": "el partido unidad social cristiana se inspira en el humanismo y los principios socialcristianos de libertad, solidaridad, democracia y justicia social. misi\u00f3n ser un partido eficaz e innovador al proponer y ejecutar sus propuestas; participativo al actuar y transparente y autocr\u00edtico al rendir cuentas para aumentar la cercan\u00eda con los habitantes de costa rica. visi\u00f3n ser reconocido y respaldado por la ciudadan\u00eda como un partido serio, renovado, diferente, participativo, innovador y comprometido con trasformar al pa\u00eds en una costa rica mejor por los problemas que resuelve y las oportunidades que crea para sus ciudadanos. valores que nos distinguen cumplimiento: estamos comprometidos con trasformar a costa rica en una sociedad nueva, superior, pr\u00f3spera, justa y verdaderamente feliz; nuestra determinaci\u00f3n y eficacia al actuar nos permitir\u00e1 lograrlo. capacidad: tenemos experiencia y personas preparadas con recursos morales, intelectuales, espirituales y materiales, curtidos en la vida p\u00fabl",
#       "tags": null,
#       "headline": null,
#       "alternative_names": [],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "stanford research park",
#       "size": "10001+",
#       "employee_count": 2,
#       "id": "stanfordresearchpark",
#       "founded": 1951,
#       "industry": "research",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "palo alto, california, united states",
#         "locality": "palo alto",
#         "region": "california",
#         "metro": "san jose, california",
#         "country": "united states",
#         "continent": "north america",
#         "street_address": "3160 porter drive",
#         "address_line_2": "suite 200",
#         "postal_code": "94304",
#         "geo": "37.44,-122.14"
#       },
#       "linkedin_id": "24984336",
#       "linkedin_url": "linkedin.com/company/stanfordresearchpark",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/stanfordresearchpark",
#         "linkedin.com/company/24984336"
#       ],
#       "website": "stanfordresearchpark.com",
#       "ticker": null,
#       "type": "private",
#       "summary": "stanford research park is a community of and for people who seek to invent the future.\n\nwe support innovative companies in their r&d pursuits by providing modern facilities in a beautiful natural landscape, offering sustainable transportation programs, forging connections with stanford university\u2019s talent and resources, and fostering collaboration.",
#       "tags": [
#         "innovation",
#         "technology",
#         "transportation",
#         "science",
#         "i.t."
#       ],
#       "headline": "Stanford Research Park is a community of and for people who seek to invent the future.",
#       "alternative_names": [],
#       "affiliated_profiles": [
#         "stanford-research-park"
#       ]
#     },
#     {
#       "name": "summus ordo karoli, militum et religionis",
#       "size": "10001+",
#       "employee_count": 1,
#       "id": "summus-ordo-karoli-militum-et-religionis",
#       "founded": null,
#       "industry": "international affairs",
#       "naics": null,
#       "sic": null,
#       "location": null,
#       "linkedin_id": "2680647",
#       "linkedin_url": "linkedin.com/company/summus-ordo-karoli-militum-et-religionis",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/summus-ordo-karoli-militum-et-religionis",
#         "linkedin.com/company/2680647"
#       ],
#       "website": "sokmr.org",
#       "ticker": null,
#       "type": "private",
#       "summary": "la soberana orden carolingia es un organismo internacional abocado principalmente a la educaci\u00f3n, la ciencia y la cultura, con vinculaci\u00f3n en innovaci\u00f3n productiva, el bienestar social y la realizaci\u00f3n personal y espiritual del individuo y la familia. posee estatus de estado sin territorio, y como tal es sujeto de derecho internacional. la soberana orden carolingia es una de las m\u00e1s antiguas \u00f3rdenes que aun siguen vigentes.",
#       "tags": [
# ...
#           "major_group": "membership organizations",
#           "industry_group": null,
#           "industry_sector": null
#         }
#       ],
#       "location": {
#         "name": "virginia, united states",
#         "locality": null,
#         "region": "virginia",
#         "metro": null,
#         "country": "united states",
#         "continent": "north america",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": null
#       },
#       "linkedin_id": "822767",
#       "linkedin_url": "linkedin.com/company/pat-herrity-for-congress",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/pat-herrity-for-congress",
#         "linkedin.com/company/822767"
#       ],
#       "website": "patherrity.com",
#       "ticker": null,
#       "type": "private",
#       "summary": "pat herrity for congress",
#       "tags": null,
#       "headline": null,
#       "alternative_names": [
#         "pat herrity for supervisor (2007/11) \u2013 herrity for chairman (2009) - herrity for congress (2010)",
#         "pat herrity congressional campaign"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "post danmark",
#       "size": "10001+",
#       "employee_count": 2749,
#       "id": "post-danmark",
#       "founded": null,
#       "industry": "logistics and supply chain",
#       "naics": [
#         {
#           "naics_code": "4921",
#           "sector": "transportation and warehousing",
#           "sub_sector": "couriers and messengers",
#           "industry_group": "couriers and express delivery services",
#           "national_industry": null
#         }
#       ],
#       "sic": [
#         {
#           "sic_code": "42",
#           "major_group": "motor freight transportation and warehousing",
#           "industry_group": null,
#           "industry_sector": null
#         }
#       ],
#       "location": {
#         "name": "denmark",
#         "locality": null,
#         "region": null,
#         "metro": null,
#         "country": "denmark",
#         "continent": "europe",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": null
#       },
#       "linkedin_id": "3009",
#       "linkedin_url": "linkedin.com/company/post-danmark",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/post-danmark",
#         "linkedin.com/company/3009"
#       ],
#       "website": "postdanmark.dk",
#       "ticker": null,
#       "type": "private",
#       "summary": "post danmark a/s er en del af postnord. postnord er en koncern, der er etableret i forbindelse med sammenl\u00e6gningen af post danmark a/s og svenske posten ab. post danmark a/s leverer en grundl\u00e6ggende postservice til alle kunder i danmark \u2013 b\u00e5de afsendere og modtagere. denne postservice skal v\u00e6re europas bedste m\u00e5lt p\u00e5 en kombination af serviceniveau, kvalitet og pris.\n vi har befordringspligt, der sikrer befolkningen adgang til postservice p\u00e5 fastlagte vilk\u00e5r. vi har eneret til omdeling af alle breve i danmark under 50 gram.\n\n i 1995 blev monopolet for postudbringning brudt, s\u00e5 flere fik adgang til at omdele breve og pakker.\n\n i dag henter vi to tredjedele af vores \u00e5rlige oms\u00e6tning p\u00e5 ca. 11,7 mia. kr. i konkurrence med andre virksomheder.",
#       "tags": [
#         "e-handel",
#         "tredjepartslogistik",
#         "lagerh\u00e5ndtering",
#         "kommunikation",
#         "kundeanalyse",
#         "logistik",
#         "postservice"
#       ],
#       "headline": "Pakker til hele Danmark",
#       "alternative_names": [
#         "postnord i danmark",
#         "postnord danmark",
#         "post danmark a/s",
#         "post denmark",
#         "post danmark it",
#         "post danmark informationsteknologi",
#         "post danmark logistik a/s",
#         "postnord",
#         "post danmark transport",
#         "postdanmark"
#       ],
#       "affiliated_profiles": [
#         "postnord-logistics"
#       ]
#     },
#     {
#       "name": "universidad del valle de m\u00e9xico campus hispano",
#       "size": "10001+",
#       "employee_count": 34,
#       "id": "universidad-del-valle-de-m-xico-campus-hispano",
#       "founded": null,
#       "industry": "primary/secondary education",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "mexico",
#         "locality": null,
#         "region": null,
#         "metro": null,
#         "country": "mexico",
#         "continent": "north america",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": null
#       },
#       "linkedin_id": "1254007",
#       "linkedin_url": "linkedin.com/company/universidad-del-valle-de-m-xico-campus-hispano",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/universidad-del-valle-de-m-xico-campus-hispano",
#         "linkedin.com/company/1254007"
#       ],
#       "website": null,
#       "ticker": null,
#       "type": "private",
#       "summary": "universidad",
#       "tags": null,
#       "headline": null,
#       "alternative_names": [
#         "universidad del valle de m\u00e9xico campus villahermosa",
#         "universidad del valle de m\u00e9xico",
#         "universidad del valle de m\u00e9xico, hispano",
#         "universidad del valle de m\u00e9xico campus toluca",
#         "universidad del valle de mexico campus hispano",
#         "universidad del valle de m\u00e3\u0089xico campus hispano"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "nws holdings limited",
#       "size": "10001+",
#       "employee_count": 36,
#       "id": "nwsh",
#       "founded": null,
#       "industry": "investment management",
#       "naics": [
#         {
#           "naics_code": "23",
#           "sector": "construction",
#           "sub_sector": null,
#           "industry_group": null,
#           "national_industry": null
#         }
#       ],
#       "sic": [
#         {
#           "sic_code": "15",
#           "major_group": "building construction general contractors and operative builders",
#           "industry_group": null,
#           "industry_sector": null
#         }
#       ],
#       "location": {
#         "name": "central district, hong kong",
#         "locality": "central district",
#         "region": null,
#         "metro": null,
#         "country": "hong kong",
#         "continent": "asia",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": "22.28,114.15"
#       },
#       "linkedin_id": null,
#       "linkedin_url": "linkedin.com/company/nwsh",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/nwsh"
#       ],
#       "website": "nws.com.hk",
#       "ticker": null,
#       "type": "private",
#       "summary": "nws holdings limited (hong kong stock code: 659), as the diversified industries flagship of new world development company limited (hong kong stock code: 17), invests and operates a wide range of businesses predominantly in hong kong and across greater china. our core businesses include toll roads, commercial aircraft leasing, construction and insurance, while we also manage a strategic portfolio spanning sectors from environment, logistics, facilities management to transport.",
#       "tags": [
#         "logistics",
#         "aviation",
#         "facilities management",
#         "construction",
#         "strategic investments",
#         "toll roads",
#         "environmental management",
#         "insurance",
#         "transport"
#       ],
#       "headline": null,
#       "alternative_names": [
#         "far east engineering services limited (new world group)",
#         "nws management services pvt ltd",
#         "nws holdings ltd"
#       ],
#       "affiliated_profiles": [
#         "new_world_development_company_limited"
#       ]
#     },
#     {
#       "name": "biolitec espa\u00f1a",
#       "size": "10001+",
#       "employee_count": 3,
#       "id": "biolitec-esp",
#       "founded": null,
#       "industry": "hospital & health care",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "madrid, madrid, spain",
#         "locality": "madrid",
#         "region": "madrid",
#         "metro": null,
#         "country": "spain",
#         "continent": "europe",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": "40.40,-3.69"
#       },
#       "linkedin_id": null,
#       "linkedin_url": "linkedin.com/company/biolitec-esp",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/biolitec-esp"
#       ],
#       "website": null,
#       "ticker": null,
#       "type": "private",
#       "summary": "filial espa\u00f1ola de la multinacional alemana biolitec ag, especializada desde hace m\u00e1s de 25 a\u00f1os en la investigaci\u00f3n y desarrollo de soluciones para la cirug\u00eda l\u00e1ser m\u00ednimamente invasiva en m\u00faltiples \u00e1reas de cirug\u00eda especializada",
#       "tags": null,
#       "headline": null,
#       "alternative_names": [],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "thai airways international - australia. experience the world with thai.",
#       "size": "10001+",
#       "employee_count": 0,
#       "id": "thai-airways-international-australia",
#       "founded": 1960,
#       "industry": "airlines/aviation",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "queensland, australia",
#         "locality": null,
#         "region": "queensland",
#         "metro": null,
#         "country": "australia",
#         "continent": "oceania",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": null
#       },
#       "linkedin_id": null,
#       "linkedin_url": "linkedin.com/company/thai-airways-international-australia",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/thai-airways-international-australia"
#       ],
#       "website": null,
#       "ticker": null,
#       "type": "private",
#       "summary": "thai airways international is the national  thailand, celebrating 59 years flying during 2019 and 48 years flying between thailand and australia. thai connects australian travellers across the world to over 70 destinations on 4 continents and with our airline partners, allow further connections to all corners of the globe.\n\nthai is a full-service, award-winning carrier offering a choice of meals and beverages, generous luggage allowances, personal entertainment systems, frequent flyer mileage accrual and legendary hospitality on all flights from/to australia.\n\nthai flies 39 times a week from australia and is a founding member of the star alliance network. we have offices in sydney, melbourne, brisbane and perth and welcome contact from you for any assistance you may need on 1300 651 960.\n\nexperience the world's best!  thai has claimed awards from skytrax for 2019 - world's best cabin crew in asia;  world's best airport lounge spa and also a top 10 world's best airlines ranking.\n\nwe loo",
#       "tags": [
#         "special handling",
#         "flights to thailand",
#         "transportation",
#         "travel insurance",
#         "accommodation",
#         "excess luggage",
#         "flights to asia",
#         "airline",
#         "flights to europe",
#         "stopovers in thailand"
#       ],
#       "headline": "Celebrating 60 years connecting the world, THAI's award-winning in-flight service and legendary hospitality endures.",
#       "alternative_names": [
#         "thai airways international - australia. experience the world with thai."
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "oculus building consultancy",
#       "size": "10001+",
#       "employee_count": 7,
#       "id": "oculus-building-consultancy",
#       "founded": 1997,
#       "industry": "construction",
#       "naics": [
#         {
#           "naics_code": "23",
#           "sector": "construction",
#           "sub_sector": null,
#           "industry_group": null,
#           "national_industry": null
#         }
#       ],
#       "sic": [
#         {
#           "sic_code": "73",
#           "major_group": "business services",
#           "industry_group": null,
#           "industry_sector": null
#         }
#       ],
#       "location": {
#         "name": "bath, bath and north east somerset, united kingdom",
#         "locality": "bath",
#         "region": "bath and north east somerset",
#         "metro": null,
#         "country": "united kingdom",
#         "continent": "europe",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": "51.37,-2.36"
#       },
#       "linkedin_id": "2538156",
#       "linkedin_url": "linkedin.com/company/oculus-building-consultancy",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/oculus-building-consultancy",
#         "linkedin.com/company/2538156"
#       ],
#       "website": "oculusconsultancy.co.uk",
#       "ticker": null,
#       "type": "private",
#       "summary": "experts in building control, passionate about buildings oculus is an expert team of highly knowledgeable approved inspectors for building control and consultants for fire safety for properties located throughout england and wales. leaders in their field, they are advocates of early consultation, a pioneering approach that allows them to gain compliance with the concepts and requirements embodied in the building regulations, throughout the entire design and construction process. this both mitigates the risk of additional expensive design and construction costs and enables clients to maintain the integrity of their architectural vision. although their expertise spans the full range of architectural styles and building types, they do have a particular passion for historic buildings. their specialist knowledge in this area enables them to analyse and advise on the most cost-effective, least intrusive ways of fulfilling the requirements of building regulations for accessibility and fire saf",
#       "tags": [
#         "historic building consultants",
#         "expert witness",
#         "approved building control inspectors",
#         "fire risk assessment"
#       ],
#       "headline": null,
#       "alternative_names": [
#         "oculus building solutions, ltd"
#       ],
#       "affiliated_profiles": []
#     },
#     {
#       "name": "washington mutual bank",
#       "size": "10001+",
#       "employee_count": 30,
#       "id": "washington-mutual-bank",
#       "founded": null,
#       "industry": "banking",
#       "naics": null,
#       "sic": null,
#       "location": {
#         "name": "las vegas, nevada, united states",
#         "locality": "las vegas",
#         "region": "nevada",
#         "metro": "las vegas, nevada",
#         "country": "united states",
#         "continent": "north america",
#         "street_address": null,
#         "address_line_2": null,
#         "postal_code": null,
#         "geo": "36.17,-115.13"
#       },
#       "linkedin_id": "35432139",
#       "linkedin_url": "linkedin.com/company/washington-mutual-bank",
#       "facebook_url": null,
#       "twitter_url": null,
#       "profiles": [
#         "linkedin.com/company/washington-mutual-bank",
#         "linkedin.com/company/35432139"
#       ],
#       "website": null,
#       "ticker": null,
#       "type": "private",
#       "summary": null,
#       "tags": null,
#       "headline": null,
#       "alternative_names": [
#         "jpmorgan chase & co.",
#         "washington mutual bank | providian financial",
#         "washington mutual bank (previously pnc mortgage)",
#         "washington mutual",
#         "washington mutual bank / chase bank",
#         "washington mutual, inc.",
#         "washington mutual / bank united",
#         "washington mutual bank / wells fargo",
#         "american mortgage network, washington mutual",
#         "washington mutual bank/bank of america/direct mortgage wholesale"
#       ],
#       "affiliated_profiles": []
#     }
#   ],
#   "scroll_token": "10001$1.0$4112",
#   "total": 10795975
# }

# %%
"""This is the sample code of the query builder from People Data"""
#!/usr/bin/python3
import requests, json, time, csv

# TODO: Add your api key below
API_KEY = "a79cd2fea39460c9c8f8c66673d30a34a79c59654050e441b63268dcf28186c3"

# TODO: Set number of records to pull (-1 for all available records)
MAX_NUM_RECORDS = -1

# NO CHANGES NEEDED BELOW HERE
PDL_URL = "https://api.peopledatalabs.com/v5/person/search"
request_header = {
    "Content-Type": "application/json",
    "X-api-key": API_KEY
}

ES_QUERY = {
    "query": {
        "bool": {
            "must": [
                {
                    "term": {
                        "job_company_name": "twitch"
                    }
                }
            ]
        }
    }
}

num_records_to_request = 100
params = {
    "dataset": "street_address",
    "query": json.dumps(ES_QUERY),
    "size": num_records_to_request,
    "pretty": True
}

# Pull all results in multiple batches
batch = 1
all_records = []
start_time = time.time()
while batch == 1 or params["scroll_token"]:
    if MAX_NUM_RECORDS != -1:
        # Update num_records_to_request
        # Compute the number of records left to pull
        num_records_to_request = MAX_NUM_RECORDS - len(all_records)
        # Clamp this number between 0 and 100
        num_records_to_request = max(0, min(num_records_to_request, 100))

    if num_records_to_request == 0:
        break

    params["size"] = num_records_to_request
    response = requests.get(PDL_URL, headers=request_header, params=params).json()

    if batch == 1:
        print(f"{response['total']} available records in this search")

    all_records.extend(response.get("data", []))
    params["scroll_token"] = response.get("scroll_token")
    print(f"Retrieved {len(response.get('data', []))} records in batch {batch}")
    batch += 1

    if params["scroll_token"]:
        time.sleep(6)   # avoid hitting rate limit thresholds


end_time = time.time()
runtime = end_time - start_time

print(f"Successfully recovered {len(all_records)} profiles in "
      f"{batch} batches [{runtime} seconds]")


def save_profiles_to_csv(profiles, filename, fields=[], delim=","):
    """Save profiles to csv (utility function)"""

    # Define header fields
    if fields == [] and len(profiles) > 0:
        fields = profiles[0].keys()

    with open(filename, "w", encoding="utf-8") as csvfile:
        # Write csv file
        writer = csv.writer(csvfile, delimiter=delim)

        # Write Header:
        writer.writerow(fields)

        count = 0
        for profile in profiles:
            # Write Body:
            writer.writerow([profile[field] for field in fields])
            count += 1
            print(f"Wrote {count} lines to: '{filename}'")



# Use utility function to save profiles to csv
csv_header_fields = ["work_email", "full_name", "linkedin_url", "job_title", "job_company_name"]
csv_filename = "small_employee.csv"
save_profiles_to_csv(all_records, csv_filename)
# Out:
# 401 available records in this search
# Retrieved 20 records in batch 1
# Successfully recovered 20 profiles in 2 batches [7.038753509521484 seconds]
# Wrote 1 lines to: 'small_employee.csv'
# Wrote 2 lines to: 'small_employee.csv'
# Wrote 3 lines to: 'small_employee.csv'
# Wrote 4 lines to: 'small_employee.csv'
# Wrote 5 lines to: 'small_employee.csv'
# Wrote 6 lines to: 'small_employee.csv'
# Wrote 7 lines to: 'small_employee.csv'
# Wrote 8 lines to: 'small_employee.csv'
# Wrote 9 lines to: 'small_employee.csv'
# Wrote 10 lines to: 'small_employee.csv'
# Wrote 11 lines to: 'small_employee.csv'
# Wrote 12 lines to: 'small_employee.csv'
# Wrote 13 lines to: 'small_employee.csv'
# Wrote 14 lines to: 'small_employee.csv'
# Wrote 15 lines to: 'small_employee.csv'
# Wrote 16 lines to: 'small_employee.csv'
# Wrote 17 lines to: 'small_employee.csv'
# Wrote 18 lines to: 'small_employee.csv'
# Wrote 19 lines to: 'small_employee.csv'
# Wrote 20 lines to: 'small_employee.csv'

# %%
#turn string into json
json_object = json.loads(response.text)
next_token=json_object["scroll_token"]

# %%
import pandas as pd
companies = pd.DataFrame(json_object["data"])

# %%
companies
companies.to_csv("test1.csv")

# %%
last=pd.read_csv("gross.csv")

# %%
la=last[['job_company_location_name', 'job_company_location_locality',
'job_company_location_metro', 'job_company_location_region',

# %%
la['job_company_location_street_address'].unique()
# Out:
# array(['350 bush street'], dtype=object)

# %%
import requests, json, time, csv
from plotly.io import write_html
import plotly.express as px
import pandas as pd

# %%
def map(API_KEY, company_name, size):
    """
    Purpose:
    Calls API with API_KEY to return size amount of employees from company of company_name.
    
    Return: 
    CSV file named "{company_name}{size}_employee.csv" if a file of that name doesn't already exist. This is so costly
    calls aren't repeated if we already have the dataset for them
    A plotly plot of the addresses of employees from company_name and the company HQ address.
    
    Parameters: 
    API_KEY is the string of your API key with PDL
    company_name is a string of the company's name
    size is an int of how many employees you want retrieved max. If you want all available employees, use -1"""
    
    #basic test cases
    if type(company_name) != str:
        raise TypeError
    if type(size) != int:
        raise TypeError
    if type(API_KEY) != str:
        raise TypeError   
    if len(API_KEY) < 5:
        raise ValueError
        
    csv_filename = company_name +str(size)+ "_employees.csv"
    try:
        df = pd.read_csv(csv_filename)
    except (FileNotFoundError):
        #the following is code from PDL's Query Builder https://www.peopledatalabs.com/main/query-builder
        MAX_NUM_RECORDS = size

        # NO CHANGES NEEDED BELOW HERE
        PDL_URL = "https://api.peopledatalabs.com/v5/person/search"
        request_header = {
            "Content-Type": "application/json",
            "X-api-key": API_KEY
        }

        ES_QUERY = {
            "query": {
                "bool": {
                    "must": [
                        {
                            "term": {
                                "job_company_name": company_name
                            }
                        }
                    ]
                }
            }
        }

        num_records_to_request = 100
        params = {
            "dataset": "street_address",
            "query": json.dumps(ES_QUERY),
            "size": num_records_to_request,
            "pretty": True
        }

        # Pull all results in multiple batches
        batch = 1
        all_records = []
        start_time = time.time()
        while batch == 1 or params["scroll_token"]:
            if MAX_NUM_RECORDS != -1:
                # Update num_records_to_request
                # Compute the number of records left to pull
                num_records_to_request = MAX_NUM_RECORDS - len(all_records)
                # Clamp this number between 0 and 100
                num_records_to_request = max(0, min(num_records_to_request, 100))

            if num_records_to_request == 0:
                break

            params["size"] = num_records_to_request
            response = requests.get(PDL_URL, headers=request_header, params=params).json()

            if batch == 1:
                print(f"{response['total']} available records in this search")

            all_records.extend(response.get("data", []))
            params["scroll_token"] = response.get("scroll_token")
            print(f"Retrieved {len(response.get('data', []))} records in batch {batch}")
            batch += 1

            if params["scroll_token"]:
                time.sleep(6)   # avoid hitting rate limit thresholds

        end_time = time.time()
        runtime = end_time - start_time

        print(f"Successfully recovered {len(all_records)} profiles in "
              f"{batch} batches [{runtime} seconds]")
        print("status:",response["status"], "total:",response["total"])
        #there should be a test case to check status and run an error if not 200

        def save_profiles_to_csv(profiles, filename, fields=[], delim=","):
            """Save profiles to csv (utility function)"""

            # Define header fields
            if fields == [] and len(profiles) > 0:
                fields = profiles[0].keys()

            with open(filename, "w", encoding="utf-8") as csvfile:
                # Write csv file
                writer = csv.writer(csvfile, delimiter=delim)

                # Write Header:
                writer.writerow(fields)

                count = 0
                for profile in profiles:
                    # Write Body:
                    writer.writerow([profile[field] for field in fields])
                    count += 1
                    print(f"Wrote {count} lines to: '{filename}'")

        # Use utility function to save profiles to csv
        csv_header_fields = ['job_company_location_geo', 'job_company_location_street_address',
                             'job_company_location_address_line_2',
                             'location_street_address', 'location_address_line_2', 'location_geo']
        save_profiles_to_csv(all_records, csv_filename, csv_header_fields)
    else:
        df = pd.read_csv(csv_filename)
        df = df[df['location_geo'].notnull()]
        df['lat'] = df['location_geo'].apply(lambda s: float(s.split(',')[0]))
        df['lon'] = df['location_geo'].apply(lambda s: float(s.split(',')[1]))
        # used Mapbox for map with streets
        token_name = 'pk.eyJ1IjoidHJhY3ljaGFybGVzMTA4IiwiYSI6ImNsMjJmdmUzajFmeXcza3BkOXgwOWZoNW4ifQ.bFv6klpNU8XWRbEJ0zk1Dw'
        px.set_mapbox_access_token(token_name)
        fig = px.density_mapbox(df, lat = 'lat', lon = 'lon', zoom=15, mapbox_style='carto-positron', radius = 10)
        fig.update_layout(margin={"r":0, "t":0, "l":0, "b":0})
        fig.show()
        write_html(fig, company_name + '_employees.html')

# %%
map("a79cd2fea39460c9c8f8c66673d30a34a79c59654050e441b63268dcf28186c3", "twitch", 20)
# Out:
# <div>                            <div id="74a95272-70bf-4b1e-ad11-03594374c1d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74a95272-70bf-4b1e-ad11-03594374c1d0")) {                    Plotly.newPlot(                        "74a95272-70bf-4b1e-ad11-03594374c1d0",                        [{"coloraxis":"coloraxis","hovertemplate":"lat=%{lat}<br>lon=%{lon}<extra></extra>","lat":[33.11,40.65,37.77,37.77,37.8,37.8,31.05,37.85,33.66,37.8,39.61,33.64,37.72,37.77,37.56,37.77,42.1,37.77,37.77,37.77],"lon":[-117.08,-73.95,-122.41,-122.41,-122.26,-122.26,-97.46,-122.48,-117.82,-122.26,-105.01,-117.6,-122.15,-122.41,-122.32,-122.41,-86.48,-122.41,-122.41,-122.41],"name":"","radius":10,"subplot":"mapbox","type":"densitymapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorba ...

# %%
df=pd.read_csv("small_employee.csv")

# %%
df['lat'] = df['location_geo'].apply(lambda s: float(s.split(',')[0]))
df['lon'] = df['location_geo'].apply(lambda s: float(s.split(',')[1]))
df = df[['first_name', 'lat', 'lon']]
df
# Out:
#    first_name    lat     lon
# 0     krystal  33.11 -117.08
# 1        nick  40.65  -73.95
# 2       keith  37.77 -122.41
# 3        drew  37.77 -122.41
# 4        josh  37.80 -122.26
# 5      ashley  37.80 -122.26
# 6        pete  31.05  -97.46
# 7      noëlle  37.85 -122.48
# 8      kashin  33.66 -117.82
# 9        alex  37.80 -122.26
# 10       ryan  39.61 -105.01
# 11       drew  33.64 -117.60
# 12      derek  37.72 -122.15
# 13      sloan  37.77 -122.41
# 14      moshe  37.56 -122.32
# 15    michael  37.77 -122.41
# 16      jared  42.10  -86.48
# 17      scott  37.77 -122.41
# 18       evan  37.77 -122.41
# 19      bryan  37.77 -122.41

# %%
import plotly.express as px
# !jupyter labextension install jupyterlab-plotly
# used Mapbox for map with streets
token_name = 'pk.eyJ1IjoidHJhY3ljaGFybGVzMTA4IiwiYSI6ImNsMjJmdmUzajFmeXcza3BkOXgwOWZoNW4ifQ.bFv6klpNU8XWRbEJ0zk1Dw'
px.set_mapbox_access_token(token_name)
fig = px.scatter_mapbox(df, lat = 'lat', lon = 'lon')
# Out:
# Building jupyterlab assets (production, minimized)

# %%
df = pd.read_csv("hiiii")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\MELINA~1\AppData\Local\Temp/ipykernel_14988/3159691594.py in <module>
# ----> 1 df = pd.read_csv("hiiii")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hiiii'

# %%
df
# Out:
#                              id        full_name first_name middle_initial  \
# 0   WFb9l15wV489FiyyHxtmvw_0000  krystal herring    krystal              l
# 1   Wq6pma-6TEFyPoTLvjolrA_0000      nick tejeda       nick              s
# 2   FSFdTHHzx55cb8Nw5jNc5A_0000  keith thornhill      keith            NaN
# 3   gBvNBvKpjndT0Rv9CrR8gw_0000       drew harry       drew              e
# 4   rLKL4Bh5HtLOOgAtFpDIIw_0000      josh zeidel       josh              d
# 5   ClZzjnxbSad5eAbudKvNiA_0000  ashley paramore     ashley            NaN
# 6   mzDy1omjDK9jmEUBvi9VGQ_0000   pete borchardt       pete              d
# 7   j-fHBupCyndHZVTWSdC5Cg_0000      noëlle plat     noëlle            NaN
# 8   jTohH1wLgP3sfEjg7nSm6Q_0000      kashin ross     kashin            NaN
# 9   JYESCJsFdsUBhahxtbzISg_0000      alex jetter       alex              t
# 10  hhe4U8cI4sWZC6qzqvUpow_0000      ryan gunter       ryan              s
# 11  ER8VIKk-WwmuevK-YL1RTQ_0000      drew lawton       drew              l
# 12  C1WJjwBwOBm-OH9GsiiMBA_0000    derek dowling      derek              j
# 13  I-wigmstLK2MbJPMFvJSYA_0000     sloan looney      sloan              d
# 14  mgQ79zqb0nJeKRI6lNmvGg_0000    moshe bergman      moshe              m
# 15  HNhhAsRZy9aydlaleAEz9w_0000  michael welburn    michael              r
# 16  VgVYsCh5RetWsdSCPDEG4Q_0000      jared riley      jared              m
# 17  KsoTfYRZVRSRtd8Ok0dpKA_0000     scott newton      scott              a
# 18  1FTptEn55RQL2VpyB98QEA_0000     evan freitas       evan              s
# 19  6lpm3Sedir3V40P7s2BatQ_0000  bryan christmas      bryan              s
#
#    middle_name last_initial  last_name  gender  birth_year  birth_date  ...  \
# 0          NaN            h    herring  female        1986         NaN  ...
# 1          NaN            t     tejeda    male        1989  1989-07-19  ...
# 2          NaN            t  thornhill    male        1982         NaN  ...
# 3          NaN            h      harry    male        1983         NaN  ...
# 4          NaN            z     zeidel    male        1987         NaN  ...
# 5          NaN            p   paramore  female        1986  1986-02-13  ...
# 6          NaN            b  borchardt    male        1981         NaN  ...
# 7          NaN            p       plat  female        1970  1970-12-21  ...
# 8          NaN            r       ross    male        1989  1989-05-27  ...
# 9          NaN            j     jetter    male        1986  1986-11-08  ...
# 10      shelby            g     gunter    male        1986  1986-04-08  ...
# 11         NaN            l     lawton    male        1982  1982-03-06  ...
# 12     jeffrey            d    dowling    male        1991  1991-04-07  ...
# 13       david            l     looney    male        1969  1969-08-20  ...
# 14         NaN            b    bergman    male        1982  1982-03-21  ...
# 15        ryan            w    welburn    male        1986  1986-05-15  ...
# 16     michael            r      riley    male        1982         NaN  ...
# 17      andrew            n     newton    male        1974         NaN  ...
# 18       shane            f    freitas    male        1983  1983-05-03  ...
# 19         NaN            c  christmas    male        1982  1982-05-29  ...
#
#                                             interests  \
# 0   ['human rights', 'animal welfare', 'children',...
# 1   ['social services', 'children', 'environment',...
# 2                   ['reef aquariums', 'video games']
# 3   ['teamwork', 'design', 'entrepreneurship', 're...
# 4   ['i play guitar', 'ad operations and optimizat...
# 5   ['writing', 'technology', 'art', 'color', 'hea...
# 6   ['mentoring', 'poker', 'training', 'photograph...
# 7   ['children', 'languages', 'yoga', 'traveling',...
# 8   ['programming', 'mobile app development', 'inv...
# 9                                       ['education']
# 10  ['environment', 'science and technology', 'hum...
# 11                     ['gaming', 'music', 'gadgets']
# 12  ['start ups', 'road biking', 'nfl', 'web devel...
# 13  ['nascar', 'home improvement', 'restaurants in...
# 14                                                 []
# 15                               ['programmable web']
# 16                            ['poverty alleviation']
# 17  ['ad operations', 'ad networks and ad services...
# 18                                                 []
# 19  ['mobile payments', 'mobile', 'analytics', 'cr...
#
#                                                skills  \
# 0   ['social media marketing', 'video games', 'soc...
# 1   ['digital marketing', 'broadcast', 'advertisin...
# 2   ['distributed systems', 'php', 'python', 'ruby...
# 3   ['software engineering', 'human computer inter...
# 4   ['google analytics', 'microsoft office', 'sale...
# 5   ['fundraising', 'volunteer management', 'socia...
# 6   ['bgp', 'troubleshooting', 'networking', 'ospf...
# 7   ['localization', 'translation', 'website local...
# 8   ['testing', 'test automation', 'programming', ...
# 9   ['ad networks', 'ad serving', 'ad exchanges', ...
# 10  ['troubleshooting', 'active directory', 'techn...
# 11  ['javascript', 'jquery', 'html 5', 'css', 'aja...
# 12  ['javascript', 'html', 'php', 'css', 'web deve...
# 13  ['saas', 'customer relations', 'professional s...
# 14  ['mysql', 'java', 'mongodb', 'software enginee...
# 15  ['web services', 'salesforce.com', 'javascript...
# 16  ['game development', 'video games', 'game desi...
# 17  ['online advertising', 'digital media', 'adver...
# 18  ['advertising', 'creative strategy', 'copywrit...
# 19  ['mobile advertising', 'ad networks', 'online ...
#
#                                        location_names  \
# 0   ['san francisco, california, united states', '...
# 1   ['agoura, california, united states', 'chicago...
# 2   ['houston, texas, united states', 'baton rouge...
# 3   ['rumford, rhode island, united states', 'some...
# 4   ['san francisco, california, united states', '...
# 5   ['columbus, ohio, united states', 'crestline, ...
# 6   ['appleton, wisconsin, united states', 'austin...
# 7   ["marseille, provence-alpes-cote d'azur, franc...
# 8   ['atlanta, georgia, united states', 'san luis ...
# 9   ['richmond, california, united states', 'santa...
# 10  ['denver, colorado, united states', 'estes par...
# 11  ['trabuco canyon, california, united states', ...
# 12  ['san leandro, california, united states', 'sa...
# 13  ['san francisco, california, united states', '...
# 14  ['houston, texas, united states', 'johor bahru...
# 15  ['chicago, illinois, united states', 'milwauke...
# 16  ['okemos, michigan, united states', 'saint jos...
# 17       ['san francisco, california, united states']
# 18  ['syracuse, new york, united states', 'rye, ne...
# 19  ['san francisco, california, united states', '...
#
#                                               regions  \
# 0                       ['california, united states']
# 1   ['california, united states', 'illinois, unite...
# 2   ['california, united states', 'louisiana, unit...
# 3   ['california, united states', 'rhode island, u...
# 4   ['maryland, united states', 'california, unite...
# 5   ['california, united states', 'ohio, united st...
# 6   ['wisconsin, united states', 'texas, united st...
# 7   ['california, united states', 'british columbi...
# 8   ['california, united states', 'georgia, united...
# 9                       ['california, united states']
# 10  ['california, united states', 'colorado, unite...
# 11                      ['california, united states']
# 12  ['california, united states', 'alberta, canada...
# 13  ['california, united states', 'wisconsin, unit...
# 14  ['johor, malaysia', 'california, united states...
# 15  ['queensland, australia', 'california, united ...
# 16  ['california, united states', 'washington, uni...
# 17                      ['california, united states']
# 18  ['california, united states', 'new york, unite...
# 19  ['maryland, united states', 'florida, united s...
#
#                                            countries  \
# 0                                  ['united states']
# 1                                  ['united states']
# 2                                  ['united states']
# 3                                  ['united states']
# 4                                  ['united states']
# 5                                  ['united states']
# 6                                  ['united states']
# 7   ['france', 'ireland', 'canada', 'united states']
# 8                                  ['united states']
# 9                                  ['united states']
# 10                                 ['united states']
# 11                                 ['united states']
# 12                       ['canada', 'united states']
# 13                                 ['united states']
# 14           ['malaysia', 'united states', 'israel']
# 15                    ['australia', 'united states']
# 16                                 ['united states']
# 17                                 ['united states']
# 18                                 ['united states']
# 19                                 ['united states']
#
#                                      street_addresses  \
# 0   [{'name': 'escondido, california, united state...
# 1   [{'name': 'brooklyn, new york, united states',...
# 2   [{'name': 'san francisco, california, united s...
# 3   [{'name': 'san francisco, california, united s...
# 4   [{'name': 'oakland, california, united states'...
# 5   [{'name': 'oakland, california, united states'...
# 6   [{'name': 'belton, texas, united states', 'loc...
# 7   [{'name': 'sausalito, california, united state...
# 8   [{'name': 'irvine, california, united states',...
# 9   [{'name': 'oakland, california, united states'...
# 10  [{'name': 'lyons, colorado, united states', 'l...
# 11  [{'name': 'ladera ranch, california, united st...
# 12  [{'name': 'san leandro, california, united sta...
# 13  [{'name': 'san francisco, california, united s...
# 14  [{'name': 'san mateo, california, united state...
# 15  [{'name': 'san francisco, california, united s...
# 16  [{'name': 'saint joseph, michigan, united stat...
# 17  [{'name': 'san francisco, california, united s...
# 18  [{'name': 'san francisco, california, united s...
# 19  [{'name': 'crofton, maryland, united states', ...
#
#                                            experience  \
# 0   [{'company': {'name': 'twitch', 'size': '1001-...
# 1   [{'company': {'name': 'twitch', 'size': '1001-...
# 2   [{'company': {'name': 'louisiana department of...
# 3   [{'company': {'name': 'mit media lab', 'size':...
# 4   [{'company': {'name': 'la spina italian restau...
# 5   [{'company': {'name': 'twitch', 'size': '1001-...
# 6   [{'company': {'name': 'internet tech services'...
# 7   [{'company': {'name': 'twitch', 'size': '1001-...
# 8   [{'company': {'name': 'twitch', 'size': '1001-...
# 9   [{'company': {'name': 'scribd', 'size': '201-5...
# 10  [{'company': {'name': 'bechtel corporation', '...
# 11  [{'company': {'name': 'sony electronics', 'siz...
# 12  [{'company': {'name': 'markus open source proj...
# 13  [{'company': {'name': 'zynga', 'size': '1001-5...
# 14  [{'company': {'name': 'lev academic center ( j...
# 15  [{'company': {'name': 'twitch', 'size': '1001-...
# 16  [{'company': {'name': 'smart homes and smart o...
# 17  [{'company': {'name': 'the washington post', '...
# 18  [{'company': {'name': 'bbdo worldwide', 'size'...
# 19  [{'company': {'name': 'visible measures', 'siz...
#
#                                             education  \
# 0   [{'school': {'name': 'orange glen high school'...
# 1   [{'school': {'name': 'university of michigan',...
# 2   [{'school': {'name': 'woodlawn high school', '...
# 3   [{'school': {'name': 'massachusetts institute ...
# 4   [{'school': {'name': 'phillips exeter academy'...
# 5   [{'school': {'name': 'cape fear community coll...
# 6   [{'school': {'name': 'appleton east high schoo...
# 7   [{'school': {'name': 'monterey institute of in...
# 8   [{'school': {'name': 'stone mountain high scho...
# 9   [{'school': {'name': 'piedmont high school', '...
# 10  [{'school': {'name': 'tennessee technological ...
# 11  [{'school': {'name': 'vineland high school', '...
# 12  [{'school': {'name': 'medicine hat high school...
# 13  [{'school': {'name': 'stillwater area high sch...
# 14  [{'school': {'name': 'jerusalem college', 'typ...
# 15  [{'school': {'name': 'waubonsie valley high sc...
# 16  [{'school': {'name': 'michigan state universit...
# 17  [{'school': {'name': 'washington - lee high sc...
# 18  [{'school': {'name': 'rye high school', 'type'...
# 19  [{'school': {'name': 'towson university', 'typ...
#
#                                              profiles  \
# 0   [{'network': 'linkedin', 'id': '111128962', 'u...
# 1   [{'network': 'linkedin', 'id': '102294665', 'u...
# 2   [{'network': 'linkedin', 'id': '11395029', 'ur...
# 3   [{'network': 'linkedin', 'id': '127727505', 'u...
# 4   [{'network': 'linkedin', 'id': '69536387', 'ur...
# 5   [{'network': 'linkedin', 'id': '53771340', 'ur...
# 6   [{'network': 'facebook', 'id': '521667774', 'u...
# 7   [{'network': 'linkedin', 'id': '3030649', 'url...
# 8   [{'network': 'linkedin', 'id': '146093344', 'u...
# 9   [{'network': 'linkedin', 'id': '56131662', 'ur...
# 10  [{'network': 'facebook', 'id': '52700563', 'ur...
# 11  [{'network': 'linkedin', 'id': '19882362', 'ur...
# 12  [{'network': 'linkedin', 'id': '108592893', 'u...
# 13  [{'network': 'linkedin', 'id': '1216724', 'url...
# 14  [{'network': 'linkedin', 'id': '13784420', 'ur...
# 15  [{'network': 'linkedin', 'id': '27735729', 'ur...
# 16  [{'network': 'linkedin', 'id': '80916705', 'ur...
# 17  [{'network': 'linkedin', 'id': '6427425', 'url...
# 18  [{'network': 'facebook', 'id': '5502947', 'url...
# 19  [{'network': 'facebook', 'id': '18419465', 'ur...
#
#                                        version_status
# 0   {'status': 'updated', 'contains': [], 'previou...
# 1   {'status': 'updated', 'contains': [], 'previou...
# 2   {'status': 'updated', 'contains': [], 'previou...
# 3   {'status': 'updated', 'contains': [], 'previou...
# 4   {'status': 'updated', 'contains': [], 'previou...
# 5   {'status': 'updated', 'contains': [], 'previou...
# 6   {'status': 'updated', 'contains': [], 'previou...
# 7   {'status': 'updated', 'contains': [], 'previou...
# 8   {'status': 'updated', 'contains': [], 'previou...
# 9   {'status': 'updated', 'contains': [], 'previou...
# 10  {'status': 'updated', 'contains': [], 'previou...
# 11  {'status': 'updated', 'contains': [], 'previou...
# 12  {'status': 'updated', 'contains': ['YF1neDkV2J...
# 13  {'status': 'updated', 'contains': ['yEBcuoPwwx...
# 14  {'status': 'updated', 'contains': ['gOvf0UhEKY...
# 15  {'status': 'updated', 'contains': [], 'previou...
# 16  {'status': 'updated', 'contains': [], 'previou...
# 17  {'status': 'updated', 'contains': ['LmIGdej1Dk...
# 18  {'status': 'updated', 'contains': [], 'previou...
# 19  {'status': 'updated', 'contains': [], 'previou...
#
# [20 rows x 73 columns]
